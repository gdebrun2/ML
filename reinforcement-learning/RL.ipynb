# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP11: Reinforcement Learning

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp11.zip">mp11.zip</a>.  If you want, you can also download <a href="mp11_extra.zip">mp11_extra.zip</a>, the extra credit assignment.  `mp11.zip` has the following content:
#
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp11_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `pong.py`: This is a program that plays Pong.  If called interactively, it will call the module `pong_display.py` to create a display, so that you can play.  If told to use a Q-learner, it will call your `submitted.py` to do Q-learning.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp11_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Playing Pong</a>
# 1. <a href="#section2">Creating a Q-Learner Object</a>
# 1. <a href="#section3">Epsilon-First Exploration</a>
# 1. <a href="#section4">Q-Learning</a>
# 1. <a href="#section5">Saving and Loading Your Q and N Tables</a>
# 1. <a href="#section6">Exploitation</a>
# 1. <a href="#section7">Acting</a>
# 1. <a href="#section8">Training</a>
# 1. <a href="#section9">Extra Credit</a>
# 1. <a href="#grade">Grade Your Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Playing Pong

# %% [markdown]
# Pong was the <a href="https://en.wikipedia.org/wiki/Pong">first video game produced by Atari.</a>  It is a simple game, based on table tennis.  Here is a two-person version of the game: https://commons.wikimedia.org/wiki/File:Pong_Game_Test2.gif
#
# We will be playing a one-person version of the game:
#
# * When the ball hits the top, bottom, or left wall of the playing field, it bounces.
# * The right end of the playing field is open, except for the paddle.  If the ball hits the paddle, it bounces, and the player's score increments by one.  If the ball hits the open space, the game is over; the score resets to zero, and a new game begins.
#
# The game is pretty simple, but in order to get a better feeling for it, you may want to try playing it yourself.  Use the up arrow to move the paddle upward, and the down arrow to move the paddle downward.  See how high you can make your score:

# %%
# !python pong.py
# Out:
# pygame 2.3.0 (SDL 2.24.2, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 3 rewards, 1012 frames, score 2, max score 2
# Completed 1 games, 4 rewards, 1220 frames, score 0, max score 2

# %% [markdown]
# Once you figure out how to use the arrow keys to control your paddle, we hope you will find that the game is not too hard for a human to play.  However, for a computer, it's difficult to know: where should the paddle be moved at each time step?  In order to see how difficult it is for a computer to play, let's ask the "random" player to play the game.
#
# **WARNING:** The following line will open a pygame window.  The pygame window will be hidden by this window -- in order to see it, you will need to minimize this window.  The pygame window will consume a lot of CPU time just waiting for the processor, so in order to kill it, you will need to come back to this window, click on the block below, then click the Jupyter "stop" button (the square button at the top of this window) in order to stop processing.

# %%
# !python pong.py --player random
# Out:
# pygame 2.3.0 (SDL 2.24.2, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 1 rewards, 182 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 390 frames, score 0, max score 0
# Completed 2 games, 3 rewards, 571 frames, score 0, max score 0
# Completed 3 games, 4 rewards, 752 frames, score 0, max score 0
# ^C
# Traceback (most recent call last):
#   File "/Users/jhasegaw/Dropbox/mark/teaching/ece448/ece448labs/spring23/mp11/src/pong.py", line 270, in <module>
#     application.run()
#   File "/Users/jhasegaw/Dropbox/mark/teaching/ece448/ece448labs/spring23/mp11/src/pong.py", line 170, in run
#     self.display.update_display()
#   File "/Users/jhasegaw/Dropbox/mark/teaching/ece448/ece448labs/spring23/mp11/src/pong_display.py", line 65, in update_display
#     self.fps.tick(60)
# KeyboardInterrupt

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Creating a Q-Learner Object

# %% [markdown]
# The first thing you will do is to create a `q_learner` object that can store your learned Q table and your N table (table of exploration counts).
#
# Like any other object-oriented language, python permits you to create new object classes in order to store data that will be needed from time to time.  If you are not already very, very familiar with python classes, you might want to study the python class tutorial: https://docs.python.org/3/tutorial/classes.html
#
# Like any other object in python, a `q_learner` object is created by calling its name as a function, e.g., `my_q_learner=submitted.q_learner()`.  Doing so calls the function `submitted.q_learner.__init__()`.  Let's look at the docstring to see what it should do.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.q_learner.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst, state_cardinality)
#     Create a new q_learner object.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a Q table and an N table.
#     Q[...state..., ...action...] = expected utility of state/action pair.
#     N[...state..., ...action...] = # times state/action has been explored.
#     Both are initialized to all zeros.
#     Up to you: how will you encode the state and action in order to
#     define these two lookup tables?  The state will be a list of 5 integers,
#     such that 0 <= state[i] < state_cardinality[i] for 0 <= i < 5.
#     The action will be either -1, 0, or 1.
#     It is up to you to decide how to convert an input state and action
#     into indices that you can use to access your stored Q and N tables.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#     state_cardinality (list) - cardinality of each of the quantized state variables
#
#     @return:
#     None

# %% [markdown]
# Write your `__init__` function to meet the requirements specified in the docstring.  Once you have completed it, the following code should run without errors:

# %%
importlib.reload(submitted)

q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])

print(q_learner)
# Out:
# <submitted.q_learner object at 0x1273afa90>

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Epsilon-First Exploration

# %% [markdown]
# In order to manage the exploration/exploitation tradeoff, we will be using both "epsilon-first" and "epsilon-greedy" (https://en.wikipedia.org/wiki/Multi-armed_bandit#Semi-uniform_strategies).
#
# The epsilon-first strategy explores every state/action pair at least `nfirst` times before it ever starts to exploit any strategy.  Your `q_learner` should have a table to keep track of how many times it has explored a state/action pair prior to the start of any exploitation.  The method for storing that table is up to you; in order to have some standardized API, therefore, you need to write a method called `report_exploration_counts` that returns a list of the three exploration counts for a given state.

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_exploration_counts)
# Out:
# Help on function report_exploration_counts in module submitted:
#
# report_exploration_counts(self, state)
#     Check to see how many times each action has been explored in this state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     explored_count (array of 3 ints):
#       number of times that each action has been explored from this state.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# Write `report_exploration_counts` so that it returns a list or array for any given state.  Test your code with the following:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0. 0. 0.]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0. 0. 0.]

# %% [markdown]
# When your learner first starts learning, it will call the function `choose_unexplored_action` to choose an unexplored action.  This function should choose a function uniformly at random from the set of unexplored actions in a given state, if there are any:

# %%
importlib.reload(submitted)
help(submitted.q_learner.choose_unexplored_action)
# Out:
# Help on function choose_unexplored_action in module submitted:
#
# choose_unexplored_action(self, state)
#     Choose an action that has been explored less than nfirst times.
#     If many actions are underexplored, you should choose uniformly
#     from among those actions; don't just choose the first one all
#     the time.
#
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar): either -1, or 0, or 1, or None
#       If all actions have been explored at least n_explore times, return None.
#       Otherwise, choose one uniformly at random from those w/count less than n_explore.
#       When you choose an action, you should increment its count in your counter table.

# %% [markdown]
# If this has been written correctly, the following block should generate a random sequence of actions.  If the next block produces the same action 5 times in a row, that is the wrong result, and the result would be that your code does not pass the autograder.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: -1
# Next action: 0
# Next action: 1
# Next action: 1
# Next action: 0

# %% [markdown]
# After all three actions have been explored `nfirst` times, the function `choose_unexplored_action` should return `None`, as shown here:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 0
# Next action: 1
# Next action: -1
# Next action: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# The reinforcement learning we are implementing is called Q-learning (https://en.wikipedia.org/wiki/Q-learning).
#
# Q-learning keeps a table $Q[s,a]$ that specifies the expected utility of action $a$ in state $s$.  The organization of this table is up to you.  In order to have a standard API, the first thing you should implement is a function `report_q` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_q)
# Out:
# Help on function report_q in module submitted:
#
# report_q(self, state)
#     Report the current Q values for the given state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q (array of 3 floats):
#       reward plus expected future utility of each of the three actions.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# When your `q_learner` is first initialized, the value of $Q[state,action]$ should be zero for all state/action pairs, thus the `report_q` function should return lists of zeros:

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# Q[0,0,0,0,0] is now: [0. 0. 0.]
# Q[9,9,1,1,9] is now: [0. 0. 0.]

# %% [markdown]
# There are actually many different Q-learning algorithms available, but when people refer to Q-learning with no modifier, they usually mean the time-difference (TD) algorithm.  For example, this is the algorithm that's described on the wikipedia page (https://en.wikipedia.org/wiki/Q-learning).  This is the algorithm you will implement for this MP.
#
# In supervised machine learning, the learner tries to imitate a reference label.  In reinforcement learning, there is no reference label.  Q-learning replaces the reference label with a "local Q" value, which is the utility that was obtained by performing action $a$ in state $s$ one time.  It is usually calculated like this:
#
# $$Q_{local}(s_t,a_t) = r_t + \gamma\max_{a_{t+1}}Q(s_{t+1},a_{t+1})$$
#
# where $r_t$ is the reward that was achieved by performing action $a_t$ in state $s_t$, $s_{t+1}$ is the state into which the game transitioned, and $a_{t+1}$ is one of the actions that could be performed in that state.  $Q_{local}$ is computed by your `q_local` function, which has this docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.q_local)
# Out:
# Help on function q_local in module submitted:
#
# q_local(self, reward, newstate)
#     The update to Q estimated from a single step of game play:
#     reward plus gamma times the max of Q[newstate, ...].
#
#     @param:
#     reward (scalar float): the reward achieved from the current step of game play.
#     newstate (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q_local (scalar float): the local value of Q

# %% [markdown]
# Initially, `q_local` should just return the given reward, because initially, all Q values are 0:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %% [markdown]
# Now you can use `q_learner.q_local` as the target for `q_learner.learn`.  The basic algorithm is
#
# $$Q(s,a) = Q(s,a) + \alpha (Q_{local}(s,a)-Q(s,a))$$
#
# Here is the docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Update the internal Q-table on the basis of an observed
#     state, action, reward, newstate sequence.
#
#     @params:
#     state: a list of 5 numbers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle.
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 numbers, in the same format as state
#
#     @return:
#     None

# %% [markdown]
# The following block checks a sequence of Q updates:
#
# 1. First, $Q([9,9,1,1,9],-1)$ is updated.  Since all Q values start at zero, it will be updated to just have a value equal to $\alpha$ (0.05) times the given reward (6.25) for a total value of 0.3125.
# 1. When we print out $Q([9,9,1,1,9],:)$, we see that one of the elements has been updated.
# 1. Next, update $Q([9,9,1,1,8],1)$ with a given reward, and with $[9,9,1,1,9]$ as the given next state.  Since $Q([9,9,1,1,9],-1)$ is larger than zero, the next-state Q-value should be multiplied by $\gamma$ (0.99) and added to the reward (3.1), then multiplied by $\alpha$, giving a total value of 0.17046875.
# 1. The resulting Q-value is reported.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# Q[9,9,1,1,9] is now [0.3125 0.     0.    ]
# Q[9,9,1,1,8] is now [0.         0.         0.17046875]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Saving and Loading your Q and N Tables

# %% [markdown]
# After you've spent a long time training your `q_learner`, you will want to save your Q and N tables so that you can reload them later.  The format of Q and N is up to you, therefore it's also up to you to write the `save` and `load` functions.  Here are the docstrings:

# %%
importlib.reload(submitted)
help(submitted.q_learner.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your Q and N tables to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.  We recommend numpy.savez,
#     but you can use something else if you prefer.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
importlib.reload(submitted)
help(submitted.q_learner.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load the Q and N tables from a file.
#     This should load from whatever file format your save function
#     used.  We recommend numpy.load, but you can use something
#     else if you prefer.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# These functions can be tested by doing one step of training one `q_learner`, then saving its results, then loading them into another `q_learner`:

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: -1
# N1[9,9,1,1,8] is now [1. 0. 0.]
# Q1[9,9,1,1,8] is now [0.3125 0.     0.    ]
# N2[9,9,1,1,8] starts out as [0. 0. 0.]
# Q2[9,9,1,1,8] starts out as [0. 0. 0.]
# N2[9,9,1,1,8] is now [1. 0. 0.]
# Q2[9,9,1,1,8] is now [0.3125 0.     0.    ]

# %% [markdown]
# <a id='section6'></a>

# %% [markdown]
# ## Exploitation

# %% [markdown]
# A reinforcement learner always has to trade off between exploration (choosing an action at random) versus exploitation (choosing the action with the maximum expected utility).  Before we worry about that tradeoff, though, let's first make sure that exploitation works.

# %%
importlib.reload(submitted)
help(submitted.q_learner.exploit)
# Out:
# Help on function exploit in module submitted:
#
# exploit(self, state)
#     Return the action that has the highest Q-value for the current state, and its Q-value.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar int): either -1, or 0, or 1.
#       The action that has the highest Q-value.  Ties can be broken any way you want.
#     Q (scalar float):
#       The Q-value of the selected action

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.3125 0.     0.    ]
# The best action and Q from state [9,9,1,1,9] are (-1, 0.3125)

# %% [markdown]
# <a id='section7'></a>

# %% [markdown]
# ## Acting

# %% [markdown]
# When your learner decides which action to perform, it should trade off exploration vs. exploitation using both the epsilon-first and the epsilon-greedy strategies:
# 1. If there is any action that has been explored fewer than `nfirst` times, then choose one of those actions at random.  Otherwise...
# 1. With probability `epsilon`, choose an action at random.  Otherwise...
# 1. Exploit.

# %%
importlib.reload(submitted)
help(submitted.q_learner.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     If any action has been taken less than nfirst times, then choose one of those
#     actions, uniformly at random.
#     Otherwise, with probability epsilon, choose an action uniformly at random.
#     Otherwise, choose the action with the best Q(state,action).
#
#     @params:
#     state: a list of 5 integers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %% [markdown]
# In order to test all three types of action (epsilon-first exploration, epsilon-greedy exploration, and exploitation), let's create a learner with `nfirst=1` and `epsilon=0.25`, and set it so that the best action from state `[9,9,1,1,9]` is `-1`.  With these settings, a sequence of calls to `q_learner.act` should produce the following sequence of actions:
#
# 1. The first three actions should include each possible action once.
# 1. After the first three actions, 3/4 of the remaining actions should be `-1`.  The remaining 1/4 should be randomly chosen.

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: 1
# An epsilon-first action: 0
# An epsilon-first action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# ## Training

# %% [markdown]
# Now that all of your components work, you can try training your algorithm.  Do this by giving your `q_learner` as a player to a new `pong.PongGame` object.  Set `visibility=False` so that the `PongGame` doesn't create a new window.

# %%
import pong, importlib, submitted
importlib.reload(pong)
help(pong.PongGame.__init__)
# Out:
# Help on function __init__ in module pong:
#
# __init__(self, ball_speed=4, paddle_speed=8, learner=None, visible=True, state_quantization=[10, 10, 2, 2, 10])
#     Create a new pong game, with a specified player.
#
#     @params:
#     ball_speed (scalar int) - average ball speed in pixels/frame
#     paddle_speed (scalar int) - paddle moves 0, +paddle_speed, or -paddle_speed
#     learner - can be None if the player is human.  If not None, should be an
#       object of type random_learner, submitted.q_learner, or submitted.deep_q.
#     visible (bool) - should this game have an attached pygame window?
#     state_quantization (list) - if not None, state variables are quantized
#       into integers of these cardinalities before being passed to the learner.

# %% [markdown]
# As you can see, we should set `visibility=False` so that the `PongGame` doesn't create a new window.  We should also make sure that the PongGame uses the same state quantization as the learner.

# %%
importlib.reload(pong)
importlib.reload(submitted)
state_quantization = [10,10,2,2,10]
q_learner=submitted.q_learner(0.05,0.05,0.99,5,state_quantization)

pong_game = pong.PongGame(learner=q_learner, visible=False, state_quantization=state_quantization)
print(pong_game)
# Out:
# <pong.PongGame object at 0x1272c4490>

# %% [markdown]
# In order to train our learner, we want it to play the game many times.  To do that we use the PongGame.run function:

# %%
help(pong_game.run)
# Out:
# Help on method run in module pong:
#
# run(m_rewards=inf, m_games=inf, m_frames=inf, states=[]) method of pong.PongGame instance
#     Run the game.
#     @param
#     m_frames (scalar int): maximum number of frames to be played
#     m_rewards (scalar int): maximum number of rewards earned (+ or -)
#     m_games (scalar int): maximum number of games
#     states (list): list of states whose Q-values should be returned
#        each state is a list of 5 ints: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#        and the y-position of the paddle, all quantized.
#        0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#
#     @return
#     scores (list): list of scores of all completed games
#
#     The following will be returned only if the player is q_learning or deep_q.
#     New elements will be added to these lists once/frame if m_frames is specified,
#     else once/reward if m_rewards is specified, else once/game:
#       q_achieved (list): list of the q-values of the moves that were taken
#       q_states (list): list of the q-values of requested states

# %% [markdown]
# In order to make sure our learner is learning, let's tell `pong_game.run` to output all 3 Q-values of all of the 4000 states in every time step.
#
# To make sure that's not an outrageous amount of data, let's tell it to only output the Q values once/reward, and ask it to only collect 5000 rewards:

# %%
states = [[x,y,vx,vy,py] for x in range(10) for y in range(10) for vx in range(2) for vy in range(2) for py in range(10) ]

scores, q_achieved, q_states = pong_game.run(m_rewards=500, states=states)

print('The number of games played was',len(scores))
print('The number of rewards was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 255 frames, score 0, max score 0
# Completed 1 games, 4 rewards, 817 frames, score 2, max score 2
# Completed 2 games, 5 rewards, 1071 frames, score 0, max score 2
# Completed 3 games, 6 rewards, 1279 frames, score 0, max score 2
# Completed 4 games, 7 rewards, 1460 frames, score 0, max score 2
# Completed 5 games, 9 rewards, 1801 frames, score 1, max score 2
# Completed 6 games, 10 rewards, 2055 frames, score 0, max score 2
# Completed 7 games, 11 rewards, 2263 frames, score 0, max score 2
# Completed 8 games, 12 rewards, 2444 frames, score 0, max score 2
# Completed 9 games, 13 rewards, 2698 frames, score 0, max score 2
# Completed 10 games, 16 rewards, 3222 frames, score 2, max score 2
# Completed 11 games, 17 rewards, 3430 frames, score 0, max score 2
# Completed 12 games, 18 rewards, 3611 frames, score 0, max score 2
# Completed 13 games, 19 rewards, 3792 frames, score 0, max score 2
# Completed 14 games, 20 rewards, 3973 frames, score 0, max score 2
# Completed 15 games, 21 rewards, 4181 frames, score 0, max score 2
# Completed 16 games, 22 rewards, 4435 frames, score 0, max score 2
# Completed 17 games, 23 rewards, 4643 frames, score 0, max score 2
# Completed 18 games, 24 rewards, 4851 frames, score 0, max score 2
# Completed 19 games, 25 rewards, 5105 frames, score 0, max score 2
# Completed 20 games, 26 rewards, 5359 frames, score 0, max score 2
# Completed 21 games, 29 rewards, 5944 frames, score 2, max score 2
# Completed 22 games, 30 rewards, 6152 frames, score 0, max score 2
# Completed 23 games, 31 rewards, 6360 frames, score 0, max score 2
# Completed 24 games, 32 rewards, 6614 frames, score 0, max score 2
# Completed 25 games, 33 rewards, 6822 frames, score 0, max score 2
# Completed 26 games, 34 rewards, 7003 frames, score 0, max score 2
# Completed 27 games, 35 rewards, 7257 frames, score 0, max score 2
# Completed 28 games, 36 rewards, 7438 frames, score 0, max score 2
# Completed 29 games, 37 rewards, 7619 frames, score 0, max score 2
# Completed 30 games, 38 rewards, 7800 frames, score 0, max score 2
# Completed 31 games, 39 rewards, 8054 frames, score 0, max score 2
# Completed 32 games, 41 rewards, 8551 frames, score 1, max score 2
# Completed 33 games, 43 rewards, 8934 frames, score 1, max score 2
# Completed 34 games, 45 rewards, 9668 frames, score 1, max score 2
# Completed 35 games, 46 rewards, 9849 frames, score 0, max score 2
# Completed 36 games, 47 rewards, 10030 frames, score 0, max score 2
# Completed 37 games, 48 rewards, 10284 frames, score 0, max score 2
# Completed 38 games, 50 rewards, 10667 frames, score 1, max score 2
# Completed 39 games, 51 rewards, 10848 frames, score 0, max score 2
# Completed 40 games, 52 rewards, 11056 frames, score 0, max score 2
# Completed 41 games, 53 rewards, 11310 frames, score 0, max score 2
# Completed 42 games, 54 rewards, 11491 frames, score 0, max score 2
# Completed 43 games, 55 rewards, 11745 frames, score 0, max score 2
# Completed 44 games, 57 rewards, 12335 frames, score 1, max score 2
# Completed 45 games, 58 rewards, 12516 frames, score 0, max score 2
# Completed 46 games, 59 rewards, 12770 frames, score 0, max score 2
# Completed 47 games, 60 rewards, 13024 frames, score 0, max score 2
# Completed 48 games, 63 rewards, 13578 frames, score 2, max score 2
# Completed 49 games, 64 rewards, 13759 frames, score 0, max score 2
# Completed 50 games, 65 rewards, 13940 frames, score 0, max score 2
# Completed 51 games, 66 rewards, 14194 frames, score 0, max score 2
# Completed 52 games, 67 rewards, 14375 frames, score 0, max score 2
# Completed 53 games, 68 rewards, 14556 frames, score 0, max score 2
# Completed 54 games, 69 rewards, 14764 frames, score 0, max score 2
# Completed 55 games, 70 rewards, 15018 frames, score 0, max score 2
# Completed 56 games, 71 rewards, 15226 frames, score 0, max score 2
# Completed 57 games, 72 rewards, 15434 frames, score 0, max score 2
# Completed 58 games, 73 rewards, 15642 frames, score 0, max score 2
# Completed 59 games, 75 rewards, 16232 frames, score 1, max score 2
# Completed 60 games, 76 rewards, 16413 frames, score 0, max score 2
# Completed 61 games, 77 rewards, 16594 frames, score 0, max score 2
# Completed 62 games, 78 rewards, 16802 frames, score 0, max score 2
# Completed 63 games, 79 rewards, 16983 frames, score 0, max score 2
# Completed 64 games, 81 rewards, 17599 frames, score 1, max score 2
# Completed 65 games, 82 rewards, 17853 frames, score 0, max score 2
# Completed 66 games, 84 rewards, 18247 frames, score 1, max score 2
# Completed 67 games, 85 rewards, 18455 frames, score 0, max score 2
# Completed 68 games, 86 rewards, 18709 frames, score 0, max score 2
# Completed 69 games, 87 rewards, 18963 frames, score 0, max score 2
# Completed 70 games, 88 rewards, 19144 frames, score 0, max score 2
# Completed 71 games, 89 rewards, 19325 frames, score 0, max score 2
# Completed 72 games, 91 rewards, 19762 frames, score 1, max score 2
# Completed 73 games, 92 rewards, 19943 frames, score 0, max score 2
# Completed 74 games, 93 rewards, 20124 frames, score 0, max score 2
# Completed 75 games, 94 rewards, 20332 frames, score 0, max score 2
# Completed 76 games, 95 rewards, 20513 frames, score 0, max score 2
# Completed 77 games, 96 rewards, 20721 frames, score 0, max score 2
# Completed 78 games, 98 rewards, 21272 frames, score 1, max score 2
# Completed 79 games, 99 rewards, 21526 frames, score 0, max score 2
# Completed 80 games, 105 rewards, 22560 frames, score 5, max score 5
# Completed 81 games, 106 rewards, 22814 frames, score 0, max score 5
# Completed 82 games, 107 rewards, 23068 frames, score 0, max score 5
# Completed 83 games, 108 rewards, 23276 frames, score 0, max score 5
# Completed 84 games, 109 rewards, 23484 frames, score 0, max score 5
# Completed 85 games, 111 rewards, 23867 frames, score 1, max score 5
# Completed 86 games, 112 rewards, 24048 frames, score 0, max score 5
# Completed 87 games, 113 rewards, 24229 frames, score 0, max score 5
# Completed 88 games, 114 rewards, 24483 frames, score 0, max score 5
# Completed 89 games, 116 rewards, 24822 frames, score 1, max score 5
# Completed 90 games, 118 rewards, 25319 frames, score 1, max score 5
# Completed 91 games, 119 rewards, 25573 frames, score 0, max score 5
# Completed 92 games, 121 rewards, 25944 frames, score 1, max score 5
# Completed 93 games, 122 rewards, 26152 frames, score 0, max score 5
# Completed 94 games, 123 rewards, 26406 frames, score 0, max score 5
# Completed 95 games, 124 rewards, 26614 frames, score 0, max score 5
# Completed 96 games, 125 rewards, 26822 frames, score 0, max score 5
# Completed 97 games, 126 rewards, 27003 frames, score 0, max score 5
# Completed 98 games, 127 rewards, 27184 frames, score 0, max score 5
# Completed 99 games, 128 rewards, 27438 frames, score 0, max score 5
# Completed 100 games, 129 rewards, 27619 frames, score 0, max score 5
# Completed 101 games, 131 rewards, 28353 frames, score 1, max score 5
# Completed 102 games, 132 rewards, 28534 frames, score 0, max score 5
# Completed 103 games, 134 rewards, 28939 frames, score 1, max score 5
# Completed 104 games, 136 rewards, 29291 frames, score 1, max score 5
# Completed 105 games, 138 rewards, 29697 frames, score 1, max score 5
# Completed 106 games, 141 rewards, 30364 frames, score 2, max score 5
# Completed 107 games, 143 rewards, 30798 frames, score 1, max score 5
# Completed 108 games, 144 rewards, 30979 frames, score 0, max score 5
# Completed 109 games, 145 rewards, 31187 frames, score 0, max score 5
# Completed 110 games, 146 rewards, 31395 frames, score 0, max score 5
# Completed 111 games, 149 rewards, 32036 frames, score 2, max score 5
# Completed 112 games, 153 rewards, 32899 frames, score 3, max score 5
# Completed 113 games, 155 rewards, 33633 frames, score 1, max score 5
# Completed 114 games, 156 rewards, 33814 frames, score 0, max score 5
# Completed 115 games, 157 rewards, 34022 frames, score 0, max score 5
# Completed 116 games, 159 rewards, 34482 frames, score 1, max score 5
# Completed 117 games, 160 rewards, 34690 frames, score 0, max score 5
# Completed 118 games, 162 rewards, 35057 frames, score 1, max score 5
# Completed 119 games, 163 rewards, 35265 frames, score 0, max score 5
# Completed 120 games, 164 rewards, 35473 frames, score 0, max score 5
# Completed 121 games, 165 rewards, 35727 frames, score 0, max score 5
# Completed 122 games, 166 rewards, 35935 frames, score 0, max score 5
# Completed 123 games, 167 rewards, 36189 frames, score 0, max score 5
# Completed 124 games, 168 rewards, 36443 frames, score 0, max score 5
# Completed 125 games, 169 rewards, 36697 frames, score 0, max score 5
# Completed 126 games, 170 rewards, 36951 frames, score 0, max score 5
# Completed 127 games, 171 rewards, 37132 frames, score 0, max score 5
# Completed 128 games, 172 rewards, 37313 frames, score 0, max score 5
# Completed 129 games, 173 rewards, 37521 frames, score 0, max score 5
# Completed 130 games, 174 rewards, 37775 frames, score 0, max score 5
# Completed 131 games, 175 rewards, 37983 frames, score 0, max score 5
# Completed 132 games, 176 rewards, 38164 frames, score 0, max score 5
# Completed 133 games, 177 rewards, 38345 frames, score 0, max score 5
# Completed 134 games, 179 rewards, 38808 frames, score 1, max score 5
# Completed 135 games, 180 rewards, 39062 frames, score 0, max score 5
# Completed 136 games, 182 rewards, 39445 frames, score 1, max score 5
# Completed 137 games, 183 rewards, 39653 frames, score 0, max score 5
# Completed 138 games, 184 rewards, 39834 frames, score 0, max score 5
# Completed 139 games, 185 rewards, 40015 frames, score 0, max score 5
# Completed 140 games, 186 rewards, 40196 frames, score 0, max score 5
# Completed 141 games, 190 rewards, 40982 frames, score 3, max score 5
# Completed 142 games, 192 rewards, 41460 frames, score 1, max score 5
# Completed 143 games, 194 rewards, 42122 frames, score 1, max score 5
# Completed 144 games, 196 rewards, 42784 frames, score 1, max score 5
# Completed 145 games, 197 rewards, 42965 frames, score 0, max score 5
# Completed 146 games, 198 rewards, 43146 frames, score 0, max score 5
# Completed 147 games, 199 rewards, 43327 frames, score 0, max score 5
# Completed 148 games, 201 rewards, 43870 frames, score 1, max score 5
# Completed 149 games, 202 rewards, 44078 frames, score 0, max score 5
# Completed 150 games, 203 rewards, 44332 frames, score 0, max score 5
# Completed 151 games, 207 rewards, 45175 frames, score 3, max score 5
# Completed 152 games, 208 rewards, 45383 frames, score 0, max score 5
# Completed 153 games, 210 rewards, 45789 frames, score 1, max score 5
# Completed 154 games, 213 rewards, 46297 frames, score 2, max score 5
# Completed 155 games, 214 rewards, 46505 frames, score 0, max score 5
# Completed 156 games, 215 rewards, 46713 frames, score 0, max score 5
# Completed 157 games, 217 rewards, 47150 frames, score 1, max score 5
# Completed 158 games, 218 rewards, 47331 frames, score 0, max score 5
# Completed 159 games, 219 rewards, 47539 frames, score 0, max score 5
# Completed 160 games, 220 rewards, 47720 frames, score 0, max score 5
# Completed 161 games, 222 rewards, 48296 frames, score 1, max score 5
# Completed 162 games, 223 rewards, 48550 frames, score 0, max score 5
# Completed 163 games, 226 rewards, 49446 frames, score 2, max score 5
# Completed 164 games, 227 rewards, 49700 frames, score 0, max score 5
# Completed 165 games, 228 rewards, 49954 frames, score 0, max score 5
# Completed 166 games, 230 rewards, 50417 frames, score 1, max score 5
# Completed 167 games, 231 rewards, 50625 frames, score 0, max score 5
# Completed 168 games, 232 rewards, 50879 frames, score 0, max score 5
# Completed 169 games, 233 rewards, 51133 frames, score 0, max score 5
# Completed 170 games, 234 rewards, 51387 frames, score 0, max score 5
# Completed 171 games, 235 rewards, 51595 frames, score 0, max score 5
# Completed 172 games, 236 rewards, 51849 frames, score 0, max score 5
# Completed 173 games, 237 rewards, 52103 frames, score 0, max score 5
# Completed 174 games, 238 rewards, 52357 frames, score 0, max score 5
# Completed 175 games, 239 rewards, 52565 frames, score 0, max score 5
# Completed 176 games, 240 rewards, 52819 frames, score 0, max score 5
# Completed 177 games, 241 rewards, 53027 frames, score 0, max score 5
# Completed 178 games, 242 rewards, 53235 frames, score 0, max score 5
# Completed 179 games, 243 rewards, 53443 frames, score 0, max score 5
# Completed 180 games, 244 rewards, 53697 frames, score 0, max score 5
# Completed 181 games, 245 rewards, 53951 frames, score 0, max score 5
# Completed 182 games, 249 rewards, 54711 frames, score 3, max score 5
# Completed 183 games, 250 rewards, 54892 frames, score 0, max score 5
# Completed 184 games, 251 rewards, 55073 frames, score 0, max score 5
# Completed 185 games, 252 rewards, 55281 frames, score 0, max score 5
# Completed 186 games, 253 rewards, 55462 frames, score 0, max score 5
# Completed 187 games, 254 rewards, 55643 frames, score 0, max score 5
# Completed 188 games, 257 rewards, 56886 frames, score 2, max score 5
# Completed 189 games, 258 rewards, 57067 frames, score 0, max score 5
# Completed 190 games, 259 rewards, 57275 frames, score 0, max score 5
# Completed 191 games, 260 rewards, 57483 frames, score 0, max score 5
# Completed 192 games, 261 rewards, 57664 frames, score 0, max score 5
# Completed 193 games, 262 rewards, 57872 frames, score 0, max score 5
# Completed 194 games, 264 rewards, 58309 frames, score 1, max score 5
# Completed 195 games, 266 rewards, 58650 frames, score 1, max score 5
# Completed 196 games, 268 rewards, 59312 frames, score 1, max score 5
# Completed 197 games, 269 rewards, 59520 frames, score 0, max score 5
# Completed 198 games, 270 rewards, 59728 frames, score 0, max score 5
# Completed 199 games, 273 rewards, 60682 frames, score 2, max score 5
# Completed 200 games, 277 rewards, 61311 frames, score 3, max score 5
# Completed 201 games, 278 rewards, 61565 frames, score 0, max score 5
# Completed 202 games, 280 rewards, 62036 frames, score 1, max score 5
# Completed 203 games, 281 rewards, 62217 frames, score 0, max score 5
# Completed 204 games, 283 rewards, 62608 frames, score 1, max score 5
# Completed 205 games, 284 rewards, 62816 frames, score 0, max score 5
# Completed 206 games, 285 rewards, 62997 frames, score 0, max score 5
# Completed 207 games, 286 rewards, 63178 frames, score 0, max score 5
# Completed 208 games, 288 rewards, 63690 frames, score 1, max score 5
# Completed 209 games, 292 rewards, 64628 frames, score 3, max score 5
# Completed 210 games, 293 rewards, 64809 frames, score 0, max score 5
# Completed 211 games, 294 rewards, 65017 frames, score 0, max score 5
# Completed 212 games, 295 rewards, 65271 frames, score 0, max score 5
# Completed 213 games, 296 rewards, 65525 frames, score 0, max score 5
# Completed 214 games, 299 rewards, 66432 frames, score 2, max score 5
# Completed 215 games, 300 rewards, 66686 frames, score 0, max score 5
# Completed 216 games, 301 rewards, 66894 frames, score 0, max score 5
# Completed 217 games, 302 rewards, 67075 frames, score 0, max score 5
# Completed 218 games, 304 rewards, 67609 frames, score 1, max score 5
# Completed 219 games, 305 rewards, 67817 frames, score 0, max score 5
# Completed 220 games, 307 rewards, 68280 frames, score 1, max score 5
# Completed 221 games, 308 rewards, 68461 frames, score 0, max score 5
# Completed 222 games, 310 rewards, 68871 frames, score 1, max score 5
# Completed 223 games, 312 rewards, 69223 frames, score 1, max score 5
# Completed 224 games, 313 rewards, 69431 frames, score 0, max score 5
# Completed 225 games, 314 rewards, 69685 frames, score 0, max score 5
# Completed 226 games, 315 rewards, 69866 frames, score 0, max score 5
# Completed 227 games, 316 rewards, 70074 frames, score 0, max score 5
# Completed 228 games, 318 rewards, 70736 frames, score 1, max score 5
# Completed 229 games, 319 rewards, 70917 frames, score 0, max score 5
# Completed 230 games, 321 rewards, 71377 frames, score 1, max score 5
# Completed 231 games, 322 rewards, 71631 frames, score 0, max score 5
# Completed 232 games, 323 rewards, 71839 frames, score 0, max score 5
# Completed 233 games, 324 rewards, 72020 frames, score 0, max score 5
# Completed 234 games, 325 rewards, 72274 frames, score 0, max score 5
# Completed 235 games, 328 rewards, 72815 frames, score 2, max score 5
# Completed 236 games, 329 rewards, 73069 frames, score 0, max score 5
# Completed 237 games, 330 rewards, 73277 frames, score 0, max score 5
# Completed 238 games, 331 rewards, 73458 frames, score 0, max score 5
# Completed 239 games, 332 rewards, 73666 frames, score 0, max score 5
# Completed 240 games, 334 rewards, 74080 frames, score 1, max score 5
# Completed 241 games, 335 rewards, 74334 frames, score 0, max score 5
# Completed 242 games, 337 rewards, 74734 frames, score 1, max score 5
# Completed 243 games, 338 rewards, 74988 frames, score 0, max score 5
# Completed 244 games, 339 rewards, 75242 frames, score 0, max score 5
# Completed 245 games, 341 rewards, 75750 frames, score 1, max score 5
# Completed 246 games, 342 rewards, 76004 frames, score 0, max score 5
# Completed 247 games, 345 rewards, 76790 frames, score 2, max score 5
# Completed 248 games, 348 rewards, 77539 frames, score 2, max score 5
# Completed 249 games, 349 rewards, 77747 frames, score 0, max score 5
# Completed 250 games, 350 rewards, 78001 frames, score 0, max score 5
# Completed 251 games, 351 rewards, 78209 frames, score 0, max score 5
# Completed 252 games, 352 rewards, 78417 frames, score 0, max score 5
# Completed 253 games, 353 rewards, 78598 frames, score 0, max score 5
# Completed 254 games, 354 rewards, 78852 frames, score 0, max score 5
# Completed 255 games, 356 rewards, 79403 frames, score 1, max score 5
# Completed 256 games, 358 rewards, 79874 frames, score 1, max score 5
# Completed 257 games, 359 rewards, 80082 frames, score 0, max score 5
# Completed 258 games, 360 rewards, 80336 frames, score 0, max score 5
# Completed 259 games, 364 rewards, 81342 frames, score 3, max score 5
# Completed 260 games, 365 rewards, 81550 frames, score 0, max score 5
# Completed 261 games, 366 rewards, 81804 frames, score 0, max score 5
# Completed 262 games, 367 rewards, 82012 frames, score 0, max score 5
# Completed 263 games, 369 rewards, 82931 frames, score 1, max score 5
# Completed 264 games, 371 rewards, 83521 frames, score 1, max score 5
# Completed 265 games, 372 rewards, 83775 frames, score 0, max score 5
# Completed 266 games, 375 rewards, 84527 frames, score 2, max score 5
# Completed 267 games, 376 rewards, 84735 frames, score 0, max score 5
# Completed 268 games, 377 rewards, 84989 frames, score 0, max score 5
# Completed 269 games, 378 rewards, 85197 frames, score 0, max score 5
# Completed 270 games, 381 rewards, 85897 frames, score 2, max score 5
# Completed 271 games, 382 rewards, 86105 frames, score 0, max score 5
# Completed 272 games, 384 rewards, 86457 frames, score 1, max score 5
# Completed 273 games, 385 rewards, 86638 frames, score 0, max score 5
# Completed 274 games, 388 rewards, 87185 frames, score 2, max score 5
# Completed 275 games, 389 rewards, 87366 frames, score 0, max score 5
# Completed 276 games, 392 rewards, 88218 frames, score 2, max score 5
# Completed 277 games, 394 rewards, 88655 frames, score 1, max score 5
# Completed 278 games, 395 rewards, 88836 frames, score 0, max score 5
# Completed 279 games, 397 rewards, 89755 frames, score 1, max score 5
# Completed 280 games, 398 rewards, 90009 frames, score 0, max score 5
# Completed 281 games, 399 rewards, 90263 frames, score 0, max score 5
# Completed 282 games, 404 rewards, 92538 frames, score 4, max score 5
# Completed 283 games, 406 rewards, 92890 frames, score 1, max score 5
# Completed 284 games, 408 rewards, 93402 frames, score 1, max score 5
# Completed 285 games, 409 rewards, 93610 frames, score 0, max score 5
# Completed 286 games, 412 rewards, 94527 frames, score 2, max score 5
# Completed 287 games, 415 rewards, 96798 frames, score 2, max score 5
# Completed 288 games, 416 rewards, 97052 frames, score 0, max score 5
# Completed 289 games, 417 rewards, 97233 frames, score 0, max score 5
# Completed 290 games, 418 rewards, 97441 frames, score 0, max score 5
# Completed 291 games, 420 rewards, 97846 frames, score 1, max score 5
# Completed 292 games, 423 rewards, 98454 frames, score 2, max score 5
# Completed 293 games, 426 rewards, 99434 frames, score 2, max score 5
# Completed 294 games, 430 rewards, 100200 frames, score 3, max score 5
# Completed 295 games, 431 rewards, 100408 frames, score 0, max score 5
# Completed 296 games, 432 rewards, 100589 frames, score 0, max score 5
# Completed 297 games, 433 rewards, 100843 frames, score 0, max score 5
# Completed 298 games, 435 rewards, 101355 frames, score 1, max score 5
# Completed 299 games, 439 rewards, 102201 frames, score 3, max score 5
# Completed 300 games, 440 rewards, 102409 frames, score 0, max score 5
# Completed 301 games, 446 rewards, 103198 frames, score 5, max score 5
# Completed 302 games, 447 rewards, 103379 frames, score 0, max score 5
# Completed 303 games, 449 rewards, 103747 frames, score 1, max score 5
# Completed 304 games, 450 rewards, 103955 frames, score 0, max score 5
# Completed 305 games, 451 rewards, 104163 frames, score 0, max score 5
# Completed 306 games, 452 rewards, 104417 frames, score 0, max score 5
# Completed 307 games, 455 rewards, 105069 frames, score 2, max score 5
# Completed 308 games, 459 rewards, 105865 frames, score 3, max score 5
# Completed 309 games, 460 rewards, 106046 frames, score 0, max score 5
# Completed 310 games, 461 rewards, 106300 frames, score 0, max score 5
# Completed 311 games, 462 rewards, 106481 frames, score 0, max score 5
# Completed 312 games, 466 rewards, 107109 frames, score 3, max score 5
# Completed 313 games, 468 rewards, 107522 frames, score 1, max score 5
# Completed 314 games, 472 rewards, 108634 frames, score 3, max score 5
# Completed 315 games, 473 rewards, 108842 frames, score 0, max score 5
# Completed 316 games, 476 rewards, 109748 frames, score 2, max score 5
# Completed 317 games, 477 rewards, 109929 frames, score 0, max score 5
# Completed 318 games, 479 rewards, 110327 frames, score 1, max score 5
# Completed 319 games, 481 rewards, 110835 frames, score 1, max score 5
# Completed 320 games, 482 rewards, 111016 frames, score 0, max score 5
# Completed 321 games, 484 rewards, 112283 frames, score 1, max score 5
# Completed 322 games, 487 rewards, 113321 frames, score 2, max score 5
# Completed 323 games, 489 rewards, 113689 frames, score 1, max score 5
# Completed 324 games, 493 rewards, 114668 frames, score 3, max score 5
# Completed 325 games, 494 rewards, 114922 frames, score 0, max score 5
# Completed 326 games, 495 rewards, 115176 frames, score 0, max score 5
# Completed 327 games, 496 rewards, 115430 frames, score 0, max score 5
# Completed 328 games, 498 rewards, 115981 frames, score 1, max score 5
# Completed 329 games, 499 rewards, 116162 frames, score 0, max score 5
# Completed 330 games, 500 rewards, 116370 frames, score 0, max score 5
# The number of games played was 332
# The number of rewards was 500
# The size of each returned Q-matrix was (4000, 3)

# %% [markdown]
# The returned value of `q_states` is a list of 4000x3 numpy arrays (20 states, 3 actions).  The list contains `m_rewards` of these. We want to convert it into something that matplotlib can plot.

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  1.9902443164398709

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# Text(0, 0.5, 'Reward number')

# %% [markdown]
# OK, now let's try running it for a much longer period -- say, 5000 complete games.  We won't ask it to print out any states this time.

# %%
scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])

print('The number of games played was',len(scores))
print('The number of video frames was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 182 frames, score 0, max score 5
# Completed 1 games, 8 rewards, 2474 frames, score 6, max score 6
# Completed 2 games, 9 rewards, 2682 frames, score 0, max score 6
# Completed 3 games, 10 rewards, 2863 frames, score 0, max score 6
# Completed 4 games, 11 rewards, 3044 frames, score 0, max score 6
# Completed 5 games, 12 rewards, 3225 frames, score 0, max score 6
# Completed 6 games, 13 rewards, 3433 frames, score 0, max score 6
# Completed 7 games, 15 rewards, 3930 frames, score 1, max score 6
# Completed 8 games, 17 rewards, 4664 frames, score 1, max score 6
# Completed 9 games, 21 rewards, 5387 frames, score 3, max score 6
# Completed 10 games, 23 rewards, 5739 frames, score 1, max score 6
# Completed 11 games, 26 rewards, 6304 frames, score 2, max score 6
# Completed 12 games, 27 rewards, 6558 frames, score 0, max score 6
# Completed 13 games, 28 rewards, 6739 frames, score 0, max score 6
# Completed 14 games, 33 rewards, 9729 frames, score 4, max score 6
# Completed 15 games, 45 rewards, 13251 frames, score 11, max score 11
# Completed 16 games, 46 rewards, 13459 frames, score 0, max score 11
# Completed 17 games, 47 rewards, 13667 frames, score 0, max score 11
# Completed 18 games, 48 rewards, 13921 frames, score 0, max score 11
# Completed 19 games, 49 rewards, 14102 frames, score 0, max score 11
# Completed 20 games, 51 rewards, 14614 frames, score 1, max score 11
# Completed 21 games, 61 rewards, 16218 frames, score 9, max score 11
# Completed 22 games, 63 rewards, 17137 frames, score 1, max score 11
# Completed 23 games, 66 rewards, 17832 frames, score 2, max score 11
# Completed 24 games, 67 rewards, 18013 frames, score 0, max score 11
# Completed 25 games, 69 rewards, 18441 frames, score 1, max score 11
# Completed 26 games, 70 rewards, 18649 frames, score 0, max score 11
# Completed 27 games, 73 rewards, 19290 frames, score 2, max score 11
# Completed 28 games, 74 rewards, 19544 frames, score 0, max score 11
# Completed 29 games, 75 rewards, 19798 frames, score 0, max score 11
# Completed 30 games, 76 rewards, 20006 frames, score 0, max score 11
# Completed 31 games, 80 rewards, 21541 frames, score 3, max score 11
# Completed 32 games, 81 rewards, 21722 frames, score 0, max score 11
# Completed 33 games, 87 rewards, 22740 frames, score 5, max score 11
# Completed 34 games, 89 rewards, 23123 frames, score 1, max score 11
# Completed 35 games, 90 rewards, 23304 frames, score 0, max score 11
# Completed 36 games, 92 rewards, 23724 frames, score 1, max score 11
# Completed 37 games, 94 rewards, 24152 frames, score 1, max score 11
# Completed 38 games, 96 rewards, 24664 frames, score 1, max score 11
# Completed 39 games, 97 rewards, 24918 frames, score 0, max score 11
# Completed 40 games, 101 rewards, 25879 frames, score 3, max score 11
# Completed 41 games, 102 rewards, 26060 frames, score 0, max score 11
# Completed 42 games, 104 rewards, 26566 frames, score 1, max score 11
# Completed 43 games, 105 rewards, 26820 frames, score 0, max score 11
# Completed 44 games, 106 rewards, 27074 frames, score 0, max score 11
# Completed 45 games, 107 rewards, 27328 frames, score 0, max score 11
# Completed 46 games, 109 rewards, 27742 frames, score 1, max score 11
# Completed 47 games, 113 rewards, 28734 frames, score 3, max score 11
# Completed 48 games, 114 rewards, 28915 frames, score 0, max score 11
# Completed 49 games, 115 rewards, 29169 frames, score 0, max score 11
# Completed 50 games, 116 rewards, 29423 frames, score 0, max score 11
# Completed 51 games, 120 rewards, 30480 frames, score 3, max score 11
# Completed 52 games, 123 rewards, 31137 frames, score 2, max score 11
# Completed 53 games, 125 rewards, 31597 frames, score 1, max score 11
# Completed 54 games, 127 rewards, 31938 frames, score 1, max score 11
# Completed 55 games, 133 rewards, 32884 frames, score 5, max score 11
# Completed 56 games, 135 rewards, 33251 frames, score 1, max score 11
# Completed 57 games, 139 rewards, 33986 frames, score 3, max score 11
# Completed 58 games, 141 rewards, 34483 frames, score 1, max score 11
# Completed 59 games, 142 rewards, 34737 frames, score 0, max score 11
# Completed 60 games, 143 rewards, 34918 frames, score 0, max score 11
# Completed 61 games, 144 rewards, 35126 frames, score 0, max score 11
# Completed 62 games, 146 rewards, 36045 frames, score 1, max score 11
# Completed 63 games, 148 rewards, 36397 frames, score 1, max score 11
# Completed 64 games, 150 rewards, 36765 frames, score 1, max score 11
# Completed 65 games, 151 rewards, 37019 frames, score 0, max score 11
# Completed 66 games, 152 rewards, 37227 frames, score 0, max score 11
# Completed 67 games, 154 rewards, 37715 frames, score 1, max score 11
# Completed 68 games, 156 rewards, 38634 frames, score 1, max score 11
# Completed 69 games, 157 rewards, 38888 frames, score 0, max score 11
# Completed 70 games, 158 rewards, 39142 frames, score 0, max score 11
# Completed 71 games, 160 rewards, 39540 frames, score 1, max score 11
# Completed 72 games, 161 rewards, 39794 frames, score 0, max score 11
# Completed 73 games, 163 rewards, 40135 frames, score 1, max score 11
# Completed 74 games, 165 rewards, 40529 frames, score 1, max score 11
# Completed 75 games, 166 rewards, 40710 frames, score 0, max score 11
# Completed 76 games, 167 rewards, 40918 frames, score 0, max score 11
# Completed 77 games, 170 rewards, 41676 frames, score 2, max score 11
# Completed 78 games, 171 rewards, 41884 frames, score 0, max score 11
# Completed 79 games, 173 rewards, 42225 frames, score 1, max score 11
# Completed 80 games, 174 rewards, 42479 frames, score 0, max score 11
# Completed 81 games, 176 rewards, 43081 frames, score 1, max score 11
# Completed 82 games, 177 rewards, 43335 frames, score 0, max score 11
# Completed 83 games, 180 rewards, 44383 frames, score 2, max score 11
# Completed 84 games, 184 rewards, 45116 frames, score 3, max score 11
# Completed 85 games, 187 rewards, 46809 frames, score 2, max score 11
# Completed 86 games, 188 rewards, 47017 frames, score 0, max score 11
# Completed 87 games, 190 rewards, 47751 frames, score 1, max score 11
# Completed 88 games, 191 rewards, 47959 frames, score 0, max score 11
# Completed 89 games, 194 rewards, 48685 frames, score 2, max score 11
# Completed 90 games, 195 rewards, 48893 frames, score 0, max score 11
# Completed 91 games, 196 rewards, 49101 frames, score 0, max score 11
# Completed 92 games, 197 rewards, 49282 frames, score 0, max score 11
# Completed 93 games, 198 rewards, 49490 frames, score 0, max score 11
# Completed 94 games, 201 rewards, 50044 frames, score 2, max score 11
# Completed 95 games, 202 rewards, 50298 frames, score 0, max score 11
# Completed 96 games, 204 rewards, 51032 frames, score 1, max score 11
# Completed 97 games, 205 rewards, 51240 frames, score 0, max score 11
# Completed 98 games, 207 rewards, 51668 frames, score 1, max score 11
# Completed 99 games, 208 rewards, 51849 frames, score 0, max score 11
# Completed 100 games, 209 rewards, 52057 frames, score 0, max score 11
# Completed 101 games, 210 rewards, 52311 frames, score 0, max score 11
# Completed 102 games, 212 rewards, 52679 frames, score 1, max score 11
# Completed 103 games, 213 rewards, 52860 frames, score 0, max score 11
# Completed 104 games, 214 rewards, 53068 frames, score 0, max score 11
# Completed 105 games, 215 rewards, 53276 frames, score 0, max score 11
# Completed 106 games, 216 rewards, 53484 frames, score 0, max score 11
# Completed 107 games, 217 rewards, 53692 frames, score 0, max score 11
# Completed 108 games, 218 rewards, 53873 frames, score 0, max score 11
# Completed 109 games, 221 rewards, 54956 frames, score 2, max score 11
# Completed 110 games, 223 rewards, 55370 frames, score 1, max score 11
# Completed 111 games, 224 rewards, 55624 frames, score 0, max score 11
# Completed 112 games, 228 rewards, 56636 frames, score 3, max score 11
# Completed 113 games, 230 rewards, 57298 frames, score 1, max score 11
# Completed 114 games, 232 rewards, 57726 frames, score 1, max score 11
# Completed 115 games, 233 rewards, 57980 frames, score 0, max score 11
# Completed 116 games, 234 rewards, 58161 frames, score 0, max score 11
# Completed 117 games, 236 rewards, 58598 frames, score 1, max score 11
# Completed 118 games, 237 rewards, 58779 frames, score 0, max score 11
# Completed 119 games, 238 rewards, 59033 frames, score 0, max score 11
# Completed 120 games, 239 rewards, 59214 frames, score 0, max score 11
# Completed 121 games, 241 rewards, 59597 frames, score 1, max score 11
# Completed 122 games, 242 rewards, 59851 frames, score 0, max score 11
# Completed 123 games, 245 rewards, 60819 frames, score 2, max score 11
# Completed 124 games, 247 rewards, 61370 frames, score 1, max score 11
# Completed 125 games, 252 rewards, 62314 frames, score 4, max score 11
# Completed 126 games, 254 rewards, 62742 frames, score 1, max score 11
# Completed 127 games, 259 rewards, 64336 frames, score 4, max score 11
# Completed 128 games, 260 rewards, 64590 frames, score 0, max score 11
# Completed 129 games, 263 rewards, 65236 frames, score 2, max score 11
# Completed 130 games, 265 rewards, 65826 frames, score 1, max score 11
# Completed 131 games, 266 rewards, 66080 frames, score 0, max score 11
# Completed 132 games, 269 rewards, 66574 frames, score 2, max score 11
# Completed 133 games, 270 rewards, 66755 frames, score 0, max score 11
# Completed 134 games, 275 rewards, 68306 frames, score 4, max score 11
# Completed 135 games, 276 rewards, 68487 frames, score 0, max score 11
# Completed 136 games, 279 rewards, 69287 frames, score 2, max score 11
# Completed 137 games, 282 rewards, 69960 frames, score 2, max score 11
# Completed 138 games, 284 rewards, 70343 frames, score 1, max score 11
# Completed 139 games, 285 rewards, 70524 frames, score 0, max score 11
# Completed 140 games, 287 rewards, 70961 frames, score 1, max score 11
# Completed 141 games, 293 rewards, 71950 frames, score 5, max score 11
# Completed 142 games, 294 rewards, 72131 frames, score 0, max score 11
# Completed 143 games, 296 rewards, 72499 frames, score 1, max score 11
# Completed 144 games, 298 rewards, 73050 frames, score 1, max score 11
# Completed 145 games, 301 rewards, 73620 frames, score 2, max score 11
# Completed 146 games, 302 rewards, 73828 frames, score 0, max score 11
# Completed 147 games, 304 rewards, 74340 frames, score 1, max score 11
# Completed 148 games, 305 rewards, 74594 frames, score 0, max score 11
# Completed 149 games, 307 rewards, 75091 frames, score 1, max score 11
# Completed 150 games, 308 rewards, 75299 frames, score 0, max score 11
# Completed 151 games, 310 rewards, 75640 frames, score 1, max score 11
# Completed 152 games, 313 rewards, 76217 frames, score 2, max score 11
# Completed 153 games, 314 rewards, 76425 frames, score 0, max score 11
# Completed 154 games, 315 rewards, 76633 frames, score 0, max score 11
# Completed 155 games, 318 rewards, 77712 frames, score 2, max score 11
# Completed 156 games, 320 rewards, 78126 frames, score 1, max score 11
# Completed 157 games, 323 rewards, 78679 frames, score 2, max score 11
# Completed 158 games, 326 rewards, 79180 frames, score 2, max score 11
# Completed 159 games, 328 rewards, 79521 frames, score 1, max score 11
# Completed 160 games, 330 rewards, 80183 frames, score 1, max score 11
# Completed 161 games, 335 rewards, 80999 frames, score 4, max score 11
# Completed 162 games, 336 rewards, 81180 frames, score 0, max score 11
# Completed 163 games, 337 rewards, 81361 frames, score 0, max score 11
# Completed 164 games, 341 rewards, 82387 frames, score 3, max score 11
# Completed 165 games, 347 rewards, 83311 frames, score 5, max score 11
# Completed 166 games, 348 rewards, 83565 frames, score 0, max score 11
# Completed 167 games, 349 rewards, 83819 frames, score 0, max score 11
# Completed 168 games, 350 rewards, 84000 frames, score 0, max score 11
# Completed 169 games, 352 rewards, 84383 frames, score 1, max score 11
# Completed 170 games, 355 rewards, 85231 frames, score 2, max score 11
# Completed 171 games, 358 rewards, 86380 frames, score 2, max score 11
# Completed 172 games, 359 rewards, 86588 frames, score 0, max score 11
# Completed 173 games, 360 rewards, 86769 frames, score 0, max score 11
# Completed 174 games, 363 rewards, 87617 frames, score 2, max score 11
# Completed 175 games, 364 rewards, 87825 frames, score 0, max score 11
# Completed 176 games, 366 rewards, 88205 frames, score 1, max score 11
# Completed 177 games, 369 rewards, 89004 frames, score 2, max score 11
# Completed 178 games, 373 rewards, 89844 frames, score 3, max score 11
# Completed 179 games, 377 rewards, 90530 frames, score 3, max score 11
# Completed 180 games, 379 rewards, 91042 frames, score 1, max score 11
# Completed 181 games, 380 rewards, 91296 frames, score 0, max score 11
# Completed 182 games, 383 rewards, 91922 frames, score 2, max score 11
# Completed 183 games, 384 rewards, 92130 frames, score 0, max score 11
# Completed 184 games, 387 rewards, 92621 frames, score 2, max score 11
# Completed 185 games, 389 rewards, 93027 frames, score 1, max score 11
# Completed 186 games, 391 rewards, 93395 frames, score 1, max score 11
# Completed 187 games, 392 rewards, 93576 frames, score 0, max score 11
# Completed 188 games, 393 rewards, 93784 frames, score 0, max score 11
# Completed 189 games, 399 rewards, 94616 frames, score 5, max score 11
# Completed 190 games, 401 rewards, 95278 frames, score 1, max score 11
# Completed 191 games, 403 rewards, 95645 frames, score 1, max score 11
# Completed 192 games, 405 rewards, 95986 frames, score 1, max score 11
# Completed 193 games, 407 rewards, 96354 frames, score 1, max score 11
# Completed 194 games, 414 rewards, 99639 frames, score 6, max score 11
# Completed 195 games, 419 rewards, 101602 frames, score 4, max score 11
# Completed 196 games, 420 rewards, 101810 frames, score 0, max score 11
# Completed 197 games, 421 rewards, 102064 frames, score 0, max score 11
# Completed 198 games, 424 rewards, 102615 frames, score 2, max score 11
# Completed 199 games, 425 rewards, 102796 frames, score 0, max score 11
# Completed 200 games, 426 rewards, 103050 frames, score 0, max score 11
# Completed 201 games, 427 rewards, 103258 frames, score 0, max score 11
# Completed 202 games, 428 rewards, 103512 frames, score 0, max score 11
# Completed 203 games, 432 rewards, 104632 frames, score 3, max score 11
# Completed 204 games, 433 rewards, 104813 frames, score 0, max score 11
# Completed 205 games, 435 rewards, 105310 frames, score 1, max score 11
# Completed 206 games, 436 rewards, 105518 frames, score 0, max score 11
# Completed 207 games, 437 rewards, 105699 frames, score 0, max score 11
# Completed 208 games, 442 rewards, 106971 frames, score 4, max score 11
# Completed 209 games, 443 rewards, 107179 frames, score 0, max score 11
# Completed 210 games, 446 rewards, 108043 frames, score 2, max score 11
# Completed 211 games, 449 rewards, 108677 frames, score 2, max score 11
# Completed 212 games, 451 rewards, 109174 frames, score 1, max score 11
# Completed 213 games, 455 rewards, 109881 frames, score 3, max score 11
# Completed 214 games, 457 rewards, 110800 frames, score 1, max score 11
# Completed 215 games, 458 rewards, 111054 frames, score 0, max score 11
# Completed 216 games, 459 rewards, 111235 frames, score 0, max score 11
# Completed 217 games, 461 rewards, 111825 frames, score 1, max score 11
# Completed 218 games, 462 rewards, 112006 frames, score 0, max score 11
# Completed 219 games, 466 rewards, 112681 frames, score 3, max score 11
# Completed 220 games, 469 rewards, 113194 frames, score 2, max score 11
# Completed 221 games, 472 rewards, 113674 frames, score 2, max score 11
# Completed 222 games, 473 rewards, 113855 frames, score 0, max score 11
# Completed 223 games, 474 rewards, 114063 frames, score 0, max score 11
# Completed 224 games, 476 rewards, 114982 frames, score 1, max score 11
# Completed 225 games, 479 rewards, 116532 frames, score 2, max score 11
# Completed 226 games, 485 rewards, 118090 frames, score 5, max score 11
# Completed 227 games, 486 rewards, 118298 frames, score 0, max score 11
# Completed 228 games, 491 rewards, 119249 frames, score 4, max score 11
# Completed 229 games, 493 rewards, 119983 frames, score 1, max score 11
# Completed 230 games, 495 rewards, 120420 frames, score 1, max score 11
# Completed 231 games, 496 rewards, 120674 frames, score 0, max score 11
# Completed 232 games, 497 rewards, 120928 frames, score 0, max score 11
# Completed 233 games, 498 rewards, 121136 frames, score 0, max score 11
# Completed 234 games, 499 rewards, 121390 frames, score 0, max score 11
# Completed 235 games, 502 rewards, 122152 frames, score 2, max score 11
# Completed 236 games, 503 rewards, 122406 frames, score 0, max score 11
# Completed 237 games, 506 rewards, 123071 frames, score 2, max score 11
# Completed 238 games, 509 rewards, 123579 frames, score 2, max score 11
# Completed 239 games, 510 rewards, 123760 frames, score 0, max score 11
# Completed 240 games, 514 rewards, 124519 frames, score 3, max score 11
# Completed 241 games, 516 rewards, 125016 frames, score 1, max score 11
# Completed 242 games, 518 rewards, 125453 frames, score 1, max score 11
# Completed 243 games, 522 rewards, 126209 frames, score 3, max score 11
# Completed 244 games, 523 rewards, 126417 frames, score 0, max score 11
# Completed 245 games, 526 rewards, 126969 frames, score 2, max score 11
# Completed 246 games, 528 rewards, 127352 frames, score 1, max score 11
# Completed 247 games, 531 rewards, 128044 frames, score 2, max score 11
# Completed 248 games, 535 rewards, 128735 frames, score 3, max score 11
# Completed 249 games, 540 rewards, 129568 frames, score 4, max score 11
# Completed 250 games, 543 rewards, 130287 frames, score 2, max score 11
# Completed 251 games, 544 rewards, 130541 frames, score 0, max score 11
# Completed 252 games, 545 rewards, 130722 frames, score 0, max score 11
# Completed 253 games, 549 rewards, 131655 frames, score 3, max score 11
# Completed 254 games, 551 rewards, 132574 frames, score 1, max score 11
# Completed 255 games, 553 rewards, 132957 frames, score 1, max score 11
# Completed 256 games, 554 rewards, 133138 frames, score 0, max score 11
# Completed 257 games, 555 rewards, 133346 frames, score 0, max score 11
# Completed 258 games, 556 rewards, 133554 frames, score 0, max score 11
# Completed 259 games, 557 rewards, 133735 frames, score 0, max score 11
# Completed 260 games, 558 rewards, 133916 frames, score 0, max score 11
# Completed 261 games, 561 rewards, 134694 frames, score 2, max score 11
# Completed 262 games, 565 rewards, 135502 frames, score 3, max score 11
# Completed 263 games, 569 rewards, 136522 frames, score 3, max score 11
# Completed 264 games, 570 rewards, 136730 frames, score 0, max score 11
# Completed 265 games, 574 rewards, 137426 frames, score 3, max score 11
# Completed 266 games, 576 rewards, 137889 frames, score 1, max score 11
# Completed 267 games, 577 rewards, 138143 frames, score 0, max score 11
# Completed 268 games, 579 rewards, 138603 frames, score 1, max score 11
# Completed 269 games, 580 rewards, 138811 frames, score 0, max score 11
# Completed 270 games, 582 rewards, 139239 frames, score 1, max score 11
# Completed 271 games, 586 rewards, 140346 frames, score 3, max score 11
# Completed 272 games, 588 rewards, 140687 frames, score 1, max score 11
# Completed 273 games, 590 rewards, 141052 frames, score 1, max score 11
# Completed 274 games, 592 rewards, 141515 frames, score 1, max score 11
# Completed 275 games, 593 rewards, 141696 frames, score 0, max score 11
# Completed 276 games, 594 rewards, 141877 frames, score 0, max score 11
# Completed 277 games, 595 rewards, 142085 frames, score 0, max score 11
# Completed 278 games, 600 rewards, 143351 frames, score 4, max score 11
# Completed 279 games, 606 rewards, 144596 frames, score 5, max score 11
# Completed 280 games, 609 rewards, 145407 frames, score 2, max score 11
# Completed 281 games, 610 rewards, 145615 frames, score 0, max score 11
# Completed 282 games, 612 rewards, 146075 frames, score 1, max score 11
# Completed 283 games, 614 rewards, 146737 frames, score 1, max score 11
# Completed 284 games, 619 rewards, 147914 frames, score 4, max score 11
# Completed 285 games, 620 rewards, 148122 frames, score 0, max score 11
# Completed 286 games, 622 rewards, 148673 frames, score 1, max score 11
# Completed 287 games, 625 rewards, 149199 frames, score 2, max score 11
# Completed 288 games, 627 rewards, 149750 frames, score 1, max score 11
# Completed 289 games, 628 rewards, 149931 frames, score 0, max score 11
# Completed 290 games, 629 rewards, 150185 frames, score 0, max score 11
# Completed 291 games, 635 rewards, 151758 frames, score 5, max score 11
# Completed 292 games, 637 rewards, 152292 frames, score 1, max score 11
# Completed 293 games, 638 rewards, 152500 frames, score 0, max score 11
# Completed 294 games, 640 rewards, 152983 frames, score 1, max score 11
# Completed 295 games, 644 rewards, 155150 frames, score 3, max score 11
# Completed 296 games, 645 rewards, 155404 frames, score 0, max score 11
# Completed 297 games, 647 rewards, 155756 frames, score 1, max score 11
# Completed 298 games, 651 rewards, 156503 frames, score 3, max score 11
# Completed 299 games, 653 rewards, 156879 frames, score 1, max score 11
# Completed 300 games, 655 rewards, 157229 frames, score 1, max score 11
# Completed 301 games, 658 rewards, 157940 frames, score 2, max score 11
# Completed 302 games, 661 rewards, 158435 frames, score 2, max score 11
# Completed 303 games, 663 rewards, 158787 frames, score 1, max score 11
# Completed 304 games, 665 rewards, 159250 frames, score 1, max score 11
# Completed 305 games, 667 rewards, 159617 frames, score 1, max score 11
# Completed 306 games, 674 rewards, 161801 frames, score 6, max score 11
# Completed 307 games, 677 rewards, 162520 frames, score 2, max score 11
# Completed 308 games, 686 rewards, 165432 frames, score 8, max score 11
# Completed 309 games, 687 rewards, 165640 frames, score 0, max score 11
# Completed 310 games, 689 rewards, 166137 frames, score 1, max score 11
# Completed 311 games, 691 rewards, 166799 frames, score 1, max score 11
# Completed 312 games, 696 rewards, 167652 frames, score 4, max score 11
# Completed 313 games, 698 rewards, 168080 frames, score 1, max score 11
# Completed 314 games, 700 rewards, 168953 frames, score 1, max score 11
# Completed 315 games, 701 rewards, 169161 frames, score 0, max score 11
# Completed 316 games, 702 rewards, 169342 frames, score 0, max score 11
# Completed 317 games, 716 rewards, 171918 frames, score 13, max score 13
# Completed 318 games, 719 rewards, 172766 frames, score 2, max score 13
# Completed 319 games, 721 rewards, 173203 frames, score 1, max score 13
# Completed 320 games, 724 rewards, 174258 frames, score 2, max score 13
# Completed 321 games, 726 rewards, 175177 frames, score 1, max score 13
# Completed 322 games, 727 rewards, 175385 frames, score 0, max score 13
# Completed 323 games, 729 rewards, 175726 frames, score 1, max score 13
# Completed 324 games, 738 rewards, 177619 frames, score 8, max score 13
# Completed 325 games, 740 rewards, 178025 frames, score 1, max score 13
# Completed 326 games, 742 rewards, 178508 frames, score 1, max score 13
# Completed 327 games, 743 rewards, 178689 frames, score 0, max score 13
# Completed 328 games, 745 rewards, 179201 frames, score 1, max score 13
# Completed 329 games, 750 rewards, 180705 frames, score 4, max score 13
# Completed 330 games, 753 rewards, 181237 frames, score 2, max score 13
# Completed 331 games, 757 rewards, 182464 frames, score 3, max score 13
# Completed 332 games, 761 rewards, 183356 frames, score 3, max score 13
# Completed 333 games, 762 rewards, 183537 frames, score 0, max score 13
# Completed 334 games, 763 rewards, 183745 frames, score 0, max score 13
# Completed 335 games, 764 rewards, 183953 frames, score 0, max score 13
# Completed 336 games, 768 rewards, 184816 frames, score 3, max score 13
# Completed 337 games, 773 rewards, 185777 frames, score 4, max score 13
# Completed 338 games, 774 rewards, 185958 frames, score 0, max score 13
# Completed 339 games, 775 rewards, 186139 frames, score 0, max score 13
# Completed 340 games, 780 rewards, 187208 frames, score 4, max score 13
# Completed 341 games, 781 rewards, 187389 frames, score 0, max score 13
# Completed 342 games, 786 rewards, 188319 frames, score 4, max score 13
# Completed 343 games, 792 rewards, 189361 frames, score 5, max score 13
# Completed 344 games, 793 rewards, 189615 frames, score 0, max score 13
# Completed 345 games, 795 rewards, 190052 frames, score 1, max score 13
# Completed 346 games, 796 rewards, 190260 frames, score 0, max score 13
# Completed 347 games, 799 rewards, 190861 frames, score 2, max score 13
# Completed 348 games, 800 rewards, 191115 frames, score 0, max score 13
# Completed 349 games, 804 rewards, 192346 frames, score 3, max score 13
# Completed 350 games, 810 rewards, 193438 frames, score 5, max score 13
# Completed 351 games, 811 rewards, 193619 frames, score 0, max score 13
# Completed 352 games, 812 rewards, 193827 frames, score 0, max score 13
# Completed 353 games, 813 rewards, 194081 frames, score 0, max score 13
# Completed 354 games, 814 rewards, 194289 frames, score 0, max score 13
# Completed 355 games, 816 rewards, 194695 frames, score 1, max score 13
# Completed 356 games, 824 rewards, 198781 frames, score 7, max score 13
# Completed 357 games, 826 rewards, 199218 frames, score 1, max score 13
# Completed 358 games, 830 rewards, 200489 frames, score 3, max score 13
# Completed 359 games, 832 rewards, 200917 frames, score 1, max score 13
# Completed 360 games, 837 rewards, 202063 frames, score 4, max score 13
# Completed 361 games, 839 rewards, 202982 frames, score 1, max score 13
# Completed 362 games, 841 rewards, 203533 frames, score 1, max score 13
# Completed 363 games, 847 rewards, 205250 frames, score 5, max score 13
# Completed 364 games, 851 rewards, 206253 frames, score 3, max score 13
# Completed 365 games, 861 rewards, 208739 frames, score 9, max score 13
# Completed 366 games, 862 rewards, 208947 frames, score 0, max score 13
# Completed 367 games, 866 rewards, 209594 frames, score 3, max score 13
# Completed 368 games, 867 rewards, 209848 frames, score 0, max score 13
# Completed 369 games, 868 rewards, 210029 frames, score 0, max score 13
# Completed 370 games, 870 rewards, 210434 frames, score 1, max score 13
# Completed 371 games, 876 rewards, 212357 frames, score 5, max score 13
# Completed 372 games, 880 rewards, 213056 frames, score 3, max score 13
# Completed 373 games, 885 rewards, 214042 frames, score 4, max score 13
# Completed 374 games, 888 rewards, 214768 frames, score 2, max score 13
# Completed 375 games, 890 rewards, 215231 frames, score 1, max score 13
# Completed 376 games, 893 rewards, 215987 frames, score 2, max score 13
# Completed 377 games, 895 rewards, 216567 frames, score 1, max score 13
# Completed 378 games, 899 rewards, 217282 frames, score 3, max score 13
# Completed 379 games, 901 rewards, 217719 frames, score 1, max score 13
# Completed 380 games, 902 rewards, 217927 frames, score 0, max score 13
# Completed 381 games, 903 rewards, 218135 frames, score 0, max score 13
# Completed 382 games, 904 rewards, 218343 frames, score 0, max score 13
# Completed 383 games, 910 rewards, 219563 frames, score 5, max score 13
# Completed 384 games, 912 rewards, 220000 frames, score 1, max score 13
# Completed 385 games, 914 rewards, 220662 frames, score 1, max score 13
# Completed 386 games, 915 rewards, 220916 frames, score 0, max score 13
# Completed 387 games, 920 rewards, 222162 frames, score 4, max score 13
# Completed 388 games, 923 rewards, 223161 frames, score 2, max score 13
# Completed 389 games, 924 rewards, 223415 frames, score 0, max score 13
# Completed 390 games, 925 rewards, 223669 frames, score 0, max score 13
# Completed 391 games, 929 rewards, 224791 frames, score 3, max score 13
# Completed 392 games, 930 rewards, 225045 frames, score 0, max score 13
# Completed 393 games, 935 rewards, 225995 frames, score 4, max score 13
# Completed 394 games, 936 rewards, 226249 frames, score 0, max score 13
# Completed 395 games, 937 rewards, 226430 frames, score 0, max score 13
# Completed 396 games, 940 rewards, 227041 frames, score 2, max score 13
# Completed 397 games, 941 rewards, 227222 frames, score 0, max score 13
# Completed 398 games, 942 rewards, 227403 frames, score 0, max score 13
# Completed 399 games, 945 rewards, 228171 frames, score 2, max score 13
# Completed 400 games, 949 rewards, 229088 frames, score 3, max score 13
# Completed 401 games, 951 rewards, 229525 frames, score 1, max score 13
# Completed 402 games, 954 rewards, 230168 frames, score 2, max score 13
# Completed 403 games, 955 rewards, 230349 frames, score 0, max score 13
# Completed 404 games, 956 rewards, 230557 frames, score 0, max score 13
# Completed 405 games, 958 rewards, 230994 frames, score 1, max score 13
# Completed 406 games, 962 rewards, 231766 frames, score 3, max score 13
# Completed 407 games, 966 rewards, 232884 frames, score 3, max score 13
# Completed 408 games, 969 rewards, 233611 frames, score 2, max score 13
# Completed 409 games, 970 rewards, 233865 frames, score 0, max score 13
# Completed 410 games, 973 rewards, 234255 frames, score 2, max score 13
# Completed 411 games, 976 rewards, 234972 frames, score 2, max score 13
# Completed 412 games, 980 rewards, 235720 frames, score 3, max score 13
# Completed 413 games, 987 rewards, 237236 frames, score 6, max score 13
# Completed 414 games, 990 rewards, 237773 frames, score 2, max score 13
# Completed 415 games, 992 rewards, 238171 frames, score 1, max score 13
# Completed 416 games, 999 rewards, 239846 frames, score 6, max score 13
# Completed 417 games, 1005 rewards, 241218 frames, score 5, max score 13
# Completed 418 games, 1012 rewards, 242497 frames, score 6, max score 13
# Completed 419 games, 1019 rewards, 243607 frames, score 6, max score 13
# Completed 420 games, 1022 rewards, 244098 frames, score 2, max score 13
# Completed 421 games, 1033 rewards, 246459 frames, score 10, max score 13
# Completed 422 games, 1043 rewards, 248475 frames, score 9, max score 13
# Completed 423 games, 1050 rewards, 250133 frames, score 6, max score 13
# Completed 424 games, 1054 rewards, 250943 frames, score 3, max score 13
# Completed 425 games, 1057 rewards, 251557 frames, score 2, max score 13
# Completed 426 games, 1060 rewards, 252187 frames, score 2, max score 13
# Completed 427 games, 1063 rewards, 252988 frames, score 2, max score 13
# Completed 428 games, 1065 rewards, 253539 frames, score 1, max score 13
# Completed 429 games, 1068 rewards, 254496 frames, score 2, max score 13
# Completed 430 games, 1079 rewards, 257051 frames, score 10, max score 13
# Completed 431 games, 1088 rewards, 258785 frames, score 8, max score 13
# Completed 432 games, 1092 rewards, 260047 frames, score 3, max score 13
# Completed 433 games, 1093 rewards, 260301 frames, score 0, max score 13
# Completed 434 games, 1094 rewards, 260482 frames, score 0, max score 13
# Completed 435 games, 1103 rewards, 262324 frames, score 8, max score 13
# Completed 436 games, 1111 rewards, 264294 frames, score 7, max score 13
# Completed 437 games, 1112 rewards, 264502 frames, score 0, max score 13
# Completed 438 games, 1113 rewards, 264710 frames, score 0, max score 13
# Completed 439 games, 1124 rewards, 270155 frames, score 10, max score 13
# Completed 440 games, 1127 rewards, 271090 frames, score 2, max score 13
# Completed 441 games, 1134 rewards, 272340 frames, score 6, max score 13
# Completed 442 games, 1135 rewards, 272594 frames, score 0, max score 13
# Completed 443 games, 1138 rewards, 273210 frames, score 2, max score 13
# Completed 444 games, 1140 rewards, 273683 frames, score 1, max score 13
# Completed 445 games, 1143 rewards, 275217 frames, score 2, max score 13
# Completed 446 games, 1144 rewards, 275398 frames, score 0, max score 13
# Completed 447 games, 1147 rewards, 276068 frames, score 2, max score 13
# Completed 448 games, 1151 rewards, 276898 frames, score 3, max score 13
# Completed 449 games, 1153 rewards, 277290 frames, score 1, max score 13
# Completed 450 games, 1154 rewards, 277498 frames, score 0, max score 13
# Completed 451 games, 1156 rewards, 277866 frames, score 1, max score 13
# Completed 452 games, 1164 rewards, 279430 frames, score 7, max score 13
# Completed 453 games, 1168 rewards, 280578 frames, score 3, max score 13
# Completed 454 games, 1169 rewards, 280759 frames, score 0, max score 13
# Completed 455 games, 1171 rewards, 281187 frames, score 1, max score 13
# Completed 456 games, 1175 rewards, 282696 frames, score 3, max score 13
# Completed 457 games, 1183 rewards, 284753 frames, score 7, max score 13
# Completed 458 games, 1184 rewards, 284934 frames, score 0, max score 13
# Completed 459 games, 1185 rewards, 285188 frames, score 0, max score 13
# Completed 460 games, 1187 rewards, 285685 frames, score 1, max score 13
# Completed 461 games, 1188 rewards, 285939 frames, score 0, max score 13
# Completed 462 games, 1190 rewards, 286490 frames, score 1, max score 13
# Completed 463 games, 1191 rewards, 286671 frames, score 0, max score 13
# Completed 464 games, 1194 rewards, 287151 frames, score 2, max score 13
# Completed 465 games, 1197 rewards, 287798 frames, score 2, max score 13
# Completed 466 games, 1198 rewards, 288052 frames, score 0, max score 13
# Completed 467 games, 1199 rewards, 288260 frames, score 0, max score 13
# Completed 468 games, 1200 rewards, 288514 frames, score 0, max score 13
# Completed 469 games, 1206 rewards, 289628 frames, score 5, max score 13
# Completed 470 games, 1209 rewards, 290492 frames, score 2, max score 13
# Completed 471 games, 1213 rewards, 291150 frames, score 3, max score 13
# Completed 472 games, 1217 rewards, 291854 frames, score 3, max score 13
# Completed 473 games, 1219 rewards, 292260 frames, score 1, max score 13
# Completed 474 games, 1220 rewards, 292441 frames, score 0, max score 13
# Completed 475 games, 1223 rewards, 293452 frames, score 2, max score 13
# Completed 476 games, 1226 rewards, 294562 frames, score 2, max score 13
# Completed 477 games, 1227 rewards, 294816 frames, score 0, max score 13
# Completed 478 games, 1228 rewards, 295070 frames, score 0, max score 13
# Completed 479 games, 1229 rewards, 295278 frames, score 0, max score 13
# Completed 480 games, 1230 rewards, 295486 frames, score 0, max score 13
# Completed 481 games, 1232 rewards, 296076 frames, score 1, max score 13
# Completed 482 games, 1236 rewards, 296908 frames, score 3, max score 13
# Completed 483 games, 1240 rewards, 297708 frames, score 3, max score 13
# Completed 484 games, 1245 rewards, 298663 frames, score 4, max score 13
# Completed 485 games, 1246 rewards, 298917 frames, score 0, max score 13
# Completed 486 games, 1247 rewards, 299098 frames, score 0, max score 13
# Completed 487 games, 1249 rewards, 299504 frames, score 1, max score 13
# Completed 488 games, 1252 rewards, 300051 frames, score 2, max score 13
# Completed 489 games, 1256 rewards, 300824 frames, score 3, max score 13
# Completed 490 games, 1257 rewards, 301032 frames, score 0, max score 13
# Completed 491 games, 1262 rewards, 302193 frames, score 4, max score 13
# Completed 492 games, 1264 rewards, 302560 frames, score 1, max score 13
# Completed 493 games, 1266 rewards, 302928 frames, score 1, max score 13
# Completed 494 games, 1267 rewards, 303136 frames, score 0, max score 13
# Completed 495 games, 1269 rewards, 303550 frames, score 1, max score 13
# Completed 496 games, 1270 rewards, 303804 frames, score 0, max score 13
# Completed 497 games, 1275 rewards, 304722 frames, score 4, max score 13
# Completed 498 games, 1278 rewards, 305618 frames, score 2, max score 13
# Completed 499 games, 1285 rewards, 306970 frames, score 6, max score 13
# Completed 500 games, 1286 rewards, 307178 frames, score 0, max score 13
# Completed 501 games, 1287 rewards, 307386 frames, score 0, max score 13
# Completed 502 games, 1288 rewards, 307567 frames, score 0, max score 13
# Completed 503 games, 1290 rewards, 307987 frames, score 1, max score 13
# Completed 504 games, 1292 rewards, 308401 frames, score 1, max score 13
# Completed 505 games, 1298 rewards, 309306 frames, score 5, max score 13
# Completed 506 games, 1299 rewards, 309560 frames, score 0, max score 13
# Completed 507 games, 1301 rewards, 310023 frames, score 1, max score 13
# Completed 508 games, 1305 rewards, 311786 frames, score 3, max score 13
# Completed 509 games, 1308 rewards, 312296 frames, score 2, max score 13
# Completed 510 games, 1314 rewards, 313290 frames, score 5, max score 13
# Completed 511 games, 1317 rewards, 313847 frames, score 2, max score 13
# Completed 512 games, 1319 rewards, 314581 frames, score 1, max score 13
# Completed 513 games, 1327 rewards, 315764 frames, score 7, max score 13
# Completed 514 games, 1329 rewards, 316129 frames, score 1, max score 13
# Completed 515 games, 1332 rewards, 316878 frames, score 2, max score 13
# Completed 516 games, 1334 rewards, 317375 frames, score 1, max score 13
# Completed 517 games, 1337 rewards, 318048 frames, score 2, max score 13
# Completed 518 games, 1338 rewards, 318256 frames, score 0, max score 13
# Completed 519 games, 1342 rewards, 319125 frames, score 3, max score 13
# Completed 520 games, 1346 rewards, 320069 frames, score 3, max score 13
# Completed 521 games, 1347 rewards, 320277 frames, score 0, max score 13
# Completed 522 games, 1349 rewards, 320660 frames, score 1, max score 13
# Completed 523 games, 1357 rewards, 322375 frames, score 7, max score 13
# Completed 524 games, 1361 rewards, 325076 frames, score 3, max score 13
# Completed 525 games, 1366 rewards, 326171 frames, score 4, max score 13
# Completed 526 games, 1367 rewards, 326425 frames, score 0, max score 13
# Completed 527 games, 1374 rewards, 327656 frames, score 6, max score 13
# Completed 528 games, 1376 rewards, 328070 frames, score 1, max score 13
# Completed 529 games, 1377 rewards, 328251 frames, score 0, max score 13
# Completed 530 games, 1378 rewards, 328505 frames, score 0, max score 13
# Completed 531 games, 1381 rewards, 329050 frames, score 2, max score 13
# Completed 532 games, 1383 rewards, 329601 frames, score 1, max score 13
# Completed 533 games, 1389 rewards, 330672 frames, score 5, max score 13
# Completed 534 games, 1392 rewards, 331230 frames, score 2, max score 13
# Completed 535 games, 1393 rewards, 331411 frames, score 0, max score 13
# Completed 536 games, 1398 rewards, 332504 frames, score 4, max score 13
# Completed 537 games, 1402 rewards, 333529 frames, score 3, max score 13
# Completed 538 games, 1403 rewards, 333710 frames, score 0, max score 13
# Completed 539 games, 1405 rewards, 334207 frames, score 1, max score 13
# Completed 540 games, 1408 rewards, 335449 frames, score 2, max score 13
# Completed 541 games, 1410 rewards, 335912 frames, score 1, max score 13
# Completed 542 games, 1414 rewards, 337004 frames, score 3, max score 13
# Completed 543 games, 1417 rewards, 337505 frames, score 2, max score 13
# Completed 544 games, 1425 rewards, 340312 frames, score 7, max score 13
# Completed 545 games, 1426 rewards, 340566 frames, score 0, max score 13
# Completed 546 games, 1429 rewards, 341158 frames, score 2, max score 13
# Completed 547 games, 1431 rewards, 341525 frames, score 1, max score 13
# Completed 548 games, 1432 rewards, 341733 frames, score 0, max score 13
# Completed 549 games, 1433 rewards, 341914 frames, score 0, max score 13
# Completed 550 games, 1438 rewards, 343406 frames, score 4, max score 13
# Completed 551 games, 1439 rewards, 343587 frames, score 0, max score 13
# Completed 552 games, 1441 rewards, 344121 frames, score 1, max score 13
# Completed 553 games, 1444 rewards, 345505 frames, score 2, max score 13
# Completed 554 games, 1446 rewards, 345857 frames, score 1, max score 13
# Completed 555 games, 1448 rewards, 346354 frames, score 1, max score 13
# Completed 556 games, 1450 rewards, 346706 frames, score 1, max score 13
# Completed 557 games, 1452 rewards, 347047 frames, score 1, max score 13
# Completed 558 games, 1454 rewards, 347388 frames, score 1, max score 13
# Completed 559 games, 1458 rewards, 348120 frames, score 3, max score 13
# Completed 560 games, 1466 rewards, 349527 frames, score 7, max score 13
# Completed 561 games, 1469 rewards, 350153 frames, score 2, max score 13
# Completed 562 games, 1471 rewards, 350887 frames, score 1, max score 13
# Completed 563 games, 1473 rewards, 351239 frames, score 1, max score 13
# Completed 564 games, 1481 rewards, 352757 frames, score 7, max score 13
# Completed 565 games, 1483 rewards, 353333 frames, score 1, max score 13
# Completed 566 games, 1493 rewards, 357132 frames, score 9, max score 13
# Completed 567 games, 1506 rewards, 361862 frames, score 12, max score 13
# Completed 568 games, 1509 rewards, 362470 frames, score 2, max score 13
# Completed 569 games, 1510 rewards, 362651 frames, score 0, max score 13
# Completed 570 games, 1511 rewards, 362832 frames, score 0, max score 13
# Completed 571 games, 1513 rewards, 363199 frames, score 1, max score 13
# Completed 572 games, 1515 rewards, 363551 frames, score 1, max score 13
# Completed 573 games, 1517 rewards, 364048 frames, score 1, max score 13
# Completed 574 games, 1518 rewards, 364256 frames, score 0, max score 13
# Completed 575 games, 1521 rewards, 365104 frames, score 2, max score 13
# Completed 576 games, 1531 rewards, 366993 frames, score 9, max score 13
# Completed 577 games, 1537 rewards, 368055 frames, score 5, max score 13
# Completed 578 games, 1542 rewards, 369380 frames, score 4, max score 13
# Completed 579 games, 1548 rewards, 369890 frames, score 5, max score 13
# Completed 580 games, 1555 rewards, 371597 frames, score 6, max score 13
# Completed 581 games, 1560 rewards, 372506 frames, score 4, max score 13
# Completed 582 games, 1564 rewards, 374219 frames, score 3, max score 13
# Completed 583 games, 1566 rewards, 374633 frames, score 1, max score 13
# Completed 584 games, 1581 rewards, 380668 frames, score 14, max score 14
# Completed 585 games, 1587 rewards, 381988 frames, score 5, max score 14
# Completed 586 games, 1592 rewards, 384316 frames, score 4, max score 14
# Completed 587 games, 1594 rewards, 384978 frames, score 1, max score 14
# Completed 588 games, 1598 rewards, 385644 frames, score 3, max score 14
# Completed 589 games, 1610 rewards, 387916 frames, score 11, max score 14
# Completed 590 games, 1613 rewards, 389450 frames, score 2, max score 14
# Completed 591 games, 1622 rewards, 391375 frames, score 8, max score 14
# Completed 592 games, 1624 rewards, 391835 frames, score 1, max score 14
# Completed 593 games, 1626 rewards, 392233 frames, score 1, max score 14
# Completed 594 games, 1630 rewards, 393367 frames, score 3, max score 14
# Completed 595 games, 1632 rewards, 393957 frames, score 1, max score 14
# Completed 596 games, 1640 rewards, 395386 frames, score 7, max score 14
# Completed 597 games, 1642 rewards, 395988 frames, score 1, max score 14
# Completed 598 games, 1647 rewards, 397323 frames, score 4, max score 14
# Completed 599 games, 1650 rewards, 397888 frames, score 2, max score 14
# Completed 600 games, 1651 rewards, 398096 frames, score 0, max score 14
# Completed 601 games, 1656 rewards, 399666 frames, score 4, max score 14
# Completed 602 games, 1659 rewards, 400243 frames, score 2, max score 14
# Completed 603 games, 1663 rewards, 401325 frames, score 3, max score 14
# Completed 604 games, 1665 rewards, 401762 frames, score 1, max score 14
# Completed 605 games, 1668 rewards, 402452 frames, score 2, max score 14
# Completed 606 games, 1670 rewards, 402804 frames, score 1, max score 14
# Completed 607 games, 1672 rewards, 403145 frames, score 1, max score 14
# Completed 608 games, 1673 rewards, 403326 frames, score 0, max score 14
# Completed 609 games, 1680 rewards, 404952 frames, score 6, max score 14
# Completed 610 games, 1682 rewards, 405542 frames, score 1, max score 14
# Completed 611 games, 1684 rewards, 405940 frames, score 1, max score 14
# Completed 612 games, 1689 rewards, 406975 frames, score 4, max score 14
# Completed 613 games, 1694 rewards, 408231 frames, score 4, max score 14
# Completed 614 games, 1705 rewards, 410797 frames, score 10, max score 14
# Completed 615 games, 1712 rewards, 412522 frames, score 6, max score 14
# Completed 616 games, 1721 rewards, 417620 frames, score 8, max score 14
# Completed 617 games, 1723 rewards, 418171 frames, score 1, max score 14
# Completed 618 games, 1735 rewards, 420546 frames, score 11, max score 14
# Completed 619 games, 1736 rewards, 420800 frames, score 0, max score 14
# Completed 620 games, 1738 rewards, 421263 frames, score 1, max score 14
# Completed 621 games, 1739 rewards, 421444 frames, score 0, max score 14
# Completed 622 games, 1740 rewards, 421625 frames, score 0, max score 14
# Completed 623 games, 1745 rewards, 422411 frames, score 4, max score 14
# Completed 624 games, 1751 rewards, 423717 frames, score 5, max score 14
# Completed 625 games, 1754 rewards, 424827 frames, score 2, max score 14
# Completed 626 games, 1757 rewards, 425397 frames, score 2, max score 14
# Completed 627 games, 1760 rewards, 425927 frames, score 2, max score 14
# Completed 628 games, 1767 rewards, 427684 frames, score 6, max score 14
# Completed 629 games, 1769 rewards, 428025 frames, score 1, max score 14
# Completed 630 games, 1771 rewards, 428559 frames, score 1, max score 14
# Completed 631 games, 1775 rewards, 429286 frames, score 3, max score 14
# Completed 632 games, 1784 rewards, 431343 frames, score 8, max score 14
# Completed 633 games, 1787 rewards, 431685 frames, score 2, max score 14
# Completed 634 games, 1789 rewards, 432099 frames, score 1, max score 14
# Completed 635 games, 1796 rewards, 433990 frames, score 6, max score 14
# Completed 636 games, 1802 rewards, 435214 frames, score 5, max score 14
# Completed 637 games, 1811 rewards, 437319 frames, score 8, max score 14
# Completed 638 games, 1812 rewards, 437500 frames, score 0, max score 14
# Completed 639 games, 1816 rewards, 438346 frames, score 3, max score 14
# Completed 640 games, 1822 rewards, 439652 frames, score 5, max score 14
# Completed 641 games, 1830 rewards, 440632 frames, score 7, max score 14
# Completed 642 games, 1833 rewards, 441138 frames, score 2, max score 14
# Completed 643 games, 1839 rewards, 442702 frames, score 5, max score 14
# Completed 644 games, 1851 rewards, 448031 frames, score 11, max score 14
# Completed 645 games, 1853 rewards, 448468 frames, score 1, max score 14
# Completed 646 games, 1857 rewards, 449586 frames, score 3, max score 14
# Completed 647 games, 1863 rewards, 451051 frames, score 5, max score 14
# Completed 648 games, 1873 rewards, 452870 frames, score 9, max score 14
# Completed 649 games, 1875 rewards, 453248 frames, score 1, max score 14
# Completed 650 games, 1880 rewards, 454270 frames, score 4, max score 14
# Completed 651 games, 1883 rewards, 454817 frames, score 2, max score 14
# Completed 652 games, 1891 rewards, 456315 frames, score 7, max score 14
# Completed 653 games, 1892 rewards, 456569 frames, score 0, max score 14
# Completed 654 games, 1895 rewards, 457213 frames, score 2, max score 14
# Completed 655 games, 1898 rewards, 457787 frames, score 2, max score 14
# Completed 656 games, 1899 rewards, 457995 frames, score 0, max score 14
# Completed 657 games, 1900 rewards, 458176 frames, score 0, max score 14
# Completed 658 games, 1905 rewards, 459317 frames, score 4, max score 14
# Completed 659 games, 1907 rewards, 459715 frames, score 1, max score 14
# Completed 660 games, 1914 rewards, 461735 frames, score 6, max score 14
# Completed 661 games, 1920 rewards, 462865 frames, score 5, max score 14
# Completed 662 games, 1925 rewards, 463770 frames, score 4, max score 14
# Completed 663 games, 1927 rewards, 464137 frames, score 1, max score 14
# Completed 664 games, 1929 rewards, 464597 frames, score 1, max score 14
# Completed 665 games, 1933 rewards, 465404 frames, score 3, max score 14
# Completed 666 games, 1936 rewards, 466228 frames, score 2, max score 14
# Completed 667 games, 1939 rewards, 467091 frames, score 2, max score 14
# Completed 668 games, 1950 rewards, 472019 frames, score 10, max score 14
# Completed 669 games, 1953 rewards, 472894 frames, score 2, max score 14
# Completed 670 games, 1958 rewards, 473790 frames, score 4, max score 14
# Completed 671 games, 1959 rewards, 473998 frames, score 0, max score 14
# Completed 672 games, 1978 rewards, 480766 frames, score 18, max score 18
# Completed 673 games, 1979 rewards, 480947 frames, score 0, max score 18
# Completed 674 games, 1983 rewards, 481709 frames, score 3, max score 18
# Completed 675 games, 1985 rewards, 482197 frames, score 1, max score 18
# Completed 676 games, 1988 rewards, 482878 frames, score 2, max score 18
# ...
# Completed 4795 games, 50326 rewards, 11959341 frames, score 6, max score 337
# Completed 4796 games, 50329 rewards, 11960215 frames, score 2, max score 337
# Completed 4797 games, 50355 rewards, 11970598 frames, score 25, max score 337
# Completed 4798 games, 50364 rewards, 11972190 frames, score 8, max score 337
# Completed 4799 games, 50374 rewards, 11975603 frames, score 9, max score 337
# Completed 4800 games, 50376 rewards, 11976066 frames, score 1, max score 337
# Completed 4801 games, 50388 rewards, 11978309 frames, score 11, max score 337
# Completed 4802 games, 50391 rewards, 11978885 frames, score 2, max score 337
# Completed 4803 games, 50405 rewards, 11981306 frames, score 13, max score 337
# Completed 4804 games, 50438 rewards, 11989975 frames, score 32, max score 337
# Completed 4805 games, 50445 rewards, 11991463 frames, score 6, max score 337
# Completed 4806 games, 50456 rewards, 11993270 frames, score 10, max score 337
# Completed 4807 games, 50482 rewards, 11999669 frames, score 25, max score 337
# Completed 4808 games, 50500 rewards, 12006987 frames, score 17, max score 337
# Completed 4809 games, 50504 rewards, 12008949 frames, score 3, max score 337
# Completed 4810 games, 50508 rewards, 12009884 frames, score 3, max score 337
# Completed 4811 games, 50523 rewards, 12013954 frames, score 14, max score 337
# Completed 4812 games, 50531 rewards, 12015296 frames, score 7, max score 337
# Completed 4813 games, 50540 rewards, 12016836 frames, score 8, max score 337
# Completed 4814 games, 50544 rewards, 12017777 frames, score 3, max score 337
# Completed 4815 games, 50549 rewards, 12018610 frames, score 4, max score 337
# Completed 4816 games, 50561 rewards, 12021071 frames, score 11, max score 337
# Completed 4817 games, 50581 rewards, 12025358 frames, score 19, max score 337
# Completed 4818 games, 50582 rewards, 12025539 frames, score 0, max score 337
# Completed 4819 games, 50589 rewards, 12027099 frames, score 6, max score 337
# Completed 4820 games, 50600 rewards, 12029047 frames, score 10, max score 337
# Completed 4821 games, 50603 rewards, 12029667 frames, score 2, max score 337
# Completed 4822 games, 50606 rewards, 12030540 frames, score 2, max score 337
# Completed 4823 games, 50617 rewards, 12032553 frames, score 10, max score 337
# Completed 4824 games, 50638 rewards, 12035966 frames, score 20, max score 337
# Completed 4825 games, 50657 rewards, 12039792 frames, score 18, max score 337
# Completed 4826 games, 50664 rewards, 12041044 frames, score 6, max score 337
# Completed 4827 games, 50672 rewards, 12042413 frames, score 7, max score 337
# Completed 4828 games, 50693 rewards, 12048151 frames, score 20, max score 337
# Completed 4829 games, 50704 rewards, 12050046 frames, score 10, max score 337
# Completed 4830 games, 50721 rewards, 12052656 frames, score 16, max score 337
# Completed 4831 games, 50731 rewards, 12054512 frames, score 9, max score 337
# Completed 4832 games, 50755 rewards, 12059395 frames, score 23, max score 337
# Completed 4833 games, 50760 rewards, 12060672 frames, score 4, max score 337
# Completed 4834 games, 50766 rewards, 12061738 frames, score 5, max score 337
# Completed 4835 games, 50807 rewards, 12073131 frames, score 40, max score 337
# Completed 4836 games, 50814 rewards, 12074391 frames, score 6, max score 337
# Completed 4837 games, 50816 rewards, 12074797 frames, score 1, max score 337
# Completed 4838 games, 50818 rewards, 12075138 frames, score 1, max score 337
# Completed 4839 games, 50822 rewards, 12075856 frames, score 3, max score 337
# Completed 4840 games, 50831 rewards, 12078861 frames, score 8, max score 337
# Completed 4841 games, 50835 rewards, 12079483 frames, score 3, max score 337
# Completed 4842 games, 50850 rewards, 12082172 frames, score 14, max score 337
# Completed 4843 games, 50865 rewards, 12084376 frames, score 14, max score 337
# Completed 4844 games, 50875 rewards, 12087920 frames, score 9, max score 337
# Completed 4845 games, 50878 rewards, 12088443 frames, score 2, max score 337
# Completed 4846 games, 50884 rewards, 12089511 frames, score 5, max score 337
# Completed 4847 games, 50891 rewards, 12090711 frames, score 6, max score 337
# Completed 4848 games, 50902 rewards, 12092555 frames, score 10, max score 337
# Completed 4849 games, 50907 rewards, 12093638 frames, score 4, max score 337
# Completed 4850 games, 50918 rewards, 12097168 frames, score 10, max score 337
# Completed 4851 games, 50919 rewards, 12097349 frames, score 0, max score 337
# Completed 4852 games, 50937 rewards, 12100286 frames, score 17, max score 337
# Completed 4853 games, 50970 rewards, 12115813 frames, score 32, max score 337
# Completed 4854 games, 50978 rewards, 12117089 frames, score 7, max score 337
# Completed 4855 games, 50981 rewards, 12117612 frames, score 2, max score 337
# Completed 4856 games, 50988 rewards, 12118660 frames, score 6, max score 337
# Completed 4857 games, 50991 rewards, 12119428 frames, score 2, max score 337
# Completed 4858 games, 50994 rewards, 12120115 frames, score 2, max score 337
# Completed 4859 games, 51004 rewards, 12124206 frames, score 9, max score 337
# Completed 4860 games, 51012 rewards, 12125774 frames, score 7, max score 337
# Completed 4861 games, 51043 rewards, 12131406 frames, score 30, max score 337
# Completed 4862 games, 51050 rewards, 12132572 frames, score 6, max score 337
# Completed 4863 games, 51053 rewards, 12133721 frames, score 2, max score 337
# Completed 4864 games, 51061 rewards, 12135023 frames, score 7, max score 337
# Completed 4865 games, 51071 rewards, 12136772 frames, score 9, max score 337
# Completed 4866 games, 51072 rewards, 12136953 frames, score 0, max score 337
# Completed 4867 games, 51077 rewards, 12138481 frames, score 4, max score 337
# Completed 4868 games, 51078 rewards, 12138662 frames, score 0, max score 337
# Completed 4869 games, 51082 rewards, 12139341 frames, score 3, max score 337
# Completed 4870 games, 51091 rewards, 12141074 frames, score 8, max score 337
# Completed 4871 games, 51125 rewards, 12150907 frames, score 33, max score 337
# Completed 4872 games, 51136 rewards, 12153114 frames, score 10, max score 337
# Completed 4873 games, 51142 rewards, 12154195 frames, score 5, max score 337
# Completed 4874 games, 51143 rewards, 12154449 frames, score 0, max score 337
# Completed 4875 games, 51156 rewards, 12159078 frames, score 12, max score 337
# Completed 4876 games, 51166 rewards, 12161093 frames, score 9, max score 337
# Completed 4877 games, 51171 rewards, 12162061 frames, score 4, max score 337
# Completed 4878 games, 51179 rewards, 12163805 frames, score 7, max score 337
# Completed 4879 games, 51196 rewards, 12170877 frames, score 16, max score 337
# Completed 4880 games, 51199 rewards, 12171647 frames, score 2, max score 337
# Completed 4881 games, 51212 rewards, 12173805 frames, score 12, max score 337
# Completed 4882 games, 51228 rewards, 12176472 frames, score 15, max score 337
# Completed 4883 games, 51235 rewards, 12177769 frames, score 6, max score 337
# Completed 4884 games, 51250 rewards, 12180532 frames, score 14, max score 337
# Completed 4885 games, 51265 rewards, 12182756 frames, score 14, max score 337
# Completed 4886 games, 51279 rewards, 12186072 frames, score 13, max score 337
# Completed 4887 games, 51313 rewards, 12192740 frames, score 33, max score 337
# Completed 4888 games, 51322 rewards, 12194277 frames, score 8, max score 337
# Completed 4889 games, 51352 rewards, 12199965 frames, score 29, max score 337
# Completed 4890 games, 51359 rewards, 12201571 frames, score 6, max score 337
# Completed 4891 games, 51367 rewards, 12203175 frames, score 7, max score 337
# Completed 4892 games, 51384 rewards, 12206480 frames, score 16, max score 337
# Completed 4893 games, 51399 rewards, 12209880 frames, score 14, max score 337
# Completed 4894 games, 51405 rewards, 12212709 frames, score 5, max score 337
# Completed 4895 games, 51417 rewards, 12214573 frames, score 11, max score 337
# Completed 4896 games, 51429 rewards, 12216427 frames, score 11, max score 337
# Completed 4897 games, 51449 rewards, 12222630 frames, score 19, max score 337
# Completed 4898 games, 51463 rewards, 12224883 frames, score 13, max score 337
# Completed 4899 games, 51472 rewards, 12226488 frames, score 8, max score 337
# Completed 4900 games, 51492 rewards, 12230382 frames, score 19, max score 337
# Completed 4901 games, 51503 rewards, 12232662 frames, score 10, max score 337
# Completed 4902 games, 51526 rewards, 12236905 frames, score 22, max score 337
# Completed 4903 games, 51551 rewards, 12241844 frames, score 24, max score 337
# Completed 4904 games, 51573 rewards, 12246434 frames, score 21, max score 337
# Completed 4905 games, 51579 rewards, 12247414 frames, score 5, max score 337
# Completed 4906 games, 51612 rewards, 12257069 frames, score 32, max score 337
# Completed 4907 games, 51623 rewards, 12258833 frames, score 10, max score 337
# Completed 4908 games, 51641 rewards, 12266126 frames, score 17, max score 337
# Completed 4909 games, 51648 rewards, 12267476 frames, score 6, max score 337
# Completed 4910 games, 51654 rewards, 12268615 frames, score 5, max score 337
# Completed 4911 games, 51656 rewards, 12268956 frames, score 1, max score 337
# Completed 4912 games, 51675 rewards, 12273716 frames, score 18, max score 337
# Completed 4913 games, 51688 rewards, 12278778 frames, score 12, max score 337
# Completed 4914 games, 51693 rewards, 12279630 frames, score 4, max score 337
# Completed 4915 games, 51711 rewards, 12282717 frames, score 17, max score 337
# Completed 4916 games, 51717 rewards, 12284190 frames, score 5, max score 337
# Completed 4917 games, 51725 rewards, 12286222 frames, score 7, max score 337
# Completed 4918 games, 51730 rewards, 12289619 frames, score 4, max score 337
# Completed 4919 games, 51733 rewards, 12290099 frames, score 2, max score 337
# Completed 4920 games, 51739 rewards, 12291162 frames, score 5, max score 337
# Completed 4921 games, 51768 rewards, 12301299 frames, score 28, max score 337
# Completed 4922 games, 51772 rewards, 12301930 frames, score 3, max score 337
# Completed 4923 games, 51777 rewards, 12303113 frames, score 4, max score 337
# Completed 4924 games, 51784 rewards, 12304496 frames, score 6, max score 337
# Completed 4925 games, 51795 rewards, 12307127 frames, score 10, max score 337
# Completed 4926 games, 51812 rewards, 12309760 frames, score 16, max score 337
# Completed 4927 games, 51821 rewards, 12311882 frames, score 8, max score 337
# Completed 4928 games, 51828 rewards, 12313597 frames, score 6, max score 337
# Completed 4929 games, 51852 rewards, 12318929 frames, score 23, max score 337
# Completed 4930 games, 51864 rewards, 12320850 frames, score 11, max score 337
# Completed 4931 games, 51873 rewards, 12323097 frames, score 8, max score 337
# Completed 4932 games, 51886 rewards, 12325293 frames, score 12, max score 337
# Completed 4933 games, 51897 rewards, 12326899 frames, score 10, max score 337
# Completed 4934 games, 51912 rewards, 12329210 frames, score 14, max score 337
# Completed 4935 games, 51948 rewards, 12343326 frames, score 35, max score 337
# Completed 4936 games, 51960 rewards, 12345407 frames, score 11, max score 337
# Completed 4937 games, 51961 rewards, 12345588 frames, score 0, max score 337
# Completed 4938 games, 51965 rewards, 12346461 frames, score 3, max score 337
# Completed 4939 games, 52012 rewards, 12363946 frames, score 46, max score 337
# Completed 4940 games, 52024 rewards, 12365826 frames, score 11, max score 337
# Completed 4941 games, 52040 rewards, 12368241 frames, score 15, max score 337
# Completed 4942 games, 52055 rewards, 12371009 frames, score 14, max score 337
# Completed 4943 games, 52060 rewards, 12371828 frames, score 4, max score 337
# Completed 4944 games, 52064 rewards, 12372936 frames, score 3, max score 337
# Completed 4945 games, 52068 rewards, 12373658 frames, score 3, max score 337
# Completed 4946 games, 52072 rewards, 12374492 frames, score 3, max score 337
# Completed 4947 games, 52078 rewards, 12375420 frames, score 5, max score 337
# Completed 4948 games, 52149 rewards, 12390074 frames, score 70, max score 337
# Completed 4949 games, 52175 rewards, 12394160 frames, score 25, max score 337
# Completed 4950 games, 52185 rewards, 12395956 frames, score 9, max score 337
# Completed 4951 games, 52186 rewards, 12396164 frames, score 0, max score 337
# Completed 4952 games, 52213 rewards, 12401571 frames, score 26, max score 337
# Completed 4953 games, 52214 rewards, 12401825 frames, score 0, max score 337
# Completed 4954 games, 52220 rewards, 12403440 frames, score 5, max score 337
# Completed 4955 games, 52251 rewards, 12408897 frames, score 30, max score 337
# Completed 4956 games, 52255 rewards, 12409898 frames, score 3, max score 337
# Completed 4957 games, 52256 rewards, 12410152 frames, score 0, max score 337
# Completed 4958 games, 52271 rewards, 12412472 frames, score 14, max score 337
# Completed 4959 games, 52274 rewards, 12413573 frames, score 2, max score 337
# Completed 4960 games, 52290 rewards, 12418296 frames, score 15, max score 337
# Completed 4961 games, 52308 rewards, 12421184 frames, score 17, max score 337
# Completed 4962 games, 52315 rewards, 12422647 frames, score 6, max score 337
# Completed 4963 games, 52329 rewards, 12425231 frames, score 13, max score 337
# Completed 4964 games, 52395 rewards, 12436197 frames, score 65, max score 337
# Completed 4965 games, 52411 rewards, 12439657 frames, score 15, max score 337
# Completed 4966 games, 52419 rewards, 12443140 frames, score 7, max score 337
# Completed 4967 games, 52437 rewards, 12446279 frames, score 17, max score 337
# Completed 4968 games, 52447 rewards, 12451673 frames, score 9, max score 337
# Completed 4969 games, 52454 rewards, 12452891 frames, score 6, max score 337
# Completed 4970 games, 52468 rewards, 12456610 frames, score 13, max score 337
# Completed 4971 games, 52496 rewards, 12462058 frames, score 27, max score 337
# Completed 4972 games, 52530 rewards, 12467510 frames, score 33, max score 337
# Completed 4973 games, 52532 rewards, 12468172 frames, score 1, max score 337
# Completed 4974 games, 52536 rewards, 12468842 frames, score 3, max score 337
# Completed 4975 games, 52556 rewards, 12472633 frames, score 19, max score 337
# Completed 4976 games, 52577 rewards, 12476824 frames, score 20, max score 337
# Completed 4977 games, 52587 rewards, 12478582 frames, score 9, max score 337
# Completed 4978 games, 52613 rewards, 12483230 frames, score 25, max score 337
# Completed 4979 games, 52620 rewards, 12484541 frames, score 6, max score 337
# Completed 4980 games, 52634 rewards, 12488938 frames, score 13, max score 337
# Completed 4981 games, 52675 rewards, 12500481 frames, score 40, max score 337
# Completed 4982 games, 52682 rewards, 12501809 frames, score 6, max score 337
# Completed 4983 games, 52689 rewards, 12503924 frames, score 6, max score 337
# Completed 4984 games, 52725 rewards, 12512376 frames, score 35, max score 337
# Completed 4985 games, 52727 rewards, 12512804 frames, score 1, max score 337
# Completed 4986 games, 52733 rewards, 12514264 frames, score 5, max score 337
# Completed 4987 games, 52736 rewards, 12514775 frames, score 2, max score 337
# Completed 4988 games, 52745 rewards, 12518201 frames, score 8, max score 337
# Completed 4989 games, 52752 rewards, 12519696 frames, score 6, max score 337
# Completed 4990 games, 52754 rewards, 12520102 frames, score 1, max score 337
# Completed 4991 games, 52760 rewards, 12521200 frames, score 5, max score 337
# Completed 4992 games, 52763 rewards, 12521788 frames, score 2, max score 337
# Completed 4993 games, 52779 rewards, 12524566 frames, score 15, max score 337
# Completed 4994 games, 52797 rewards, 12527617 frames, score 17, max score 337
# Completed 4995 games, 52802 rewards, 12528490 frames, score 4, max score 337
# Completed 4996 games, 52818 rewards, 12531483 frames, score 15, max score 337
# Completed 4997 games, 52823 rewards, 12532774 frames, score 4, max score 337
# Completed 4998 games, 52835 rewards, 12534742 frames, score 11, max score 337
# Completed 4999 games, 52845 rewards, 12536438 frames, score 9, max score 337
# The number of games played was 5000
# The number of video frames was 5000
# The size of each returned Q-matrix was (0,)

# %% [markdown]
# Now let's plot the score, to see if it improved over time.  We will also plot the local average, averaged over 10 consecutive games, to see if that has improved.  Notice that we can use `np.convolve` to compute the local average.
#
# These numbers are really noisy, with a really large maximum.  We will plot `np.log10(1+x)`, rather than x, so that we can better see the average numbers, and ignore the very large noisy spikes.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,9),layout='tight')
ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
ax[0].plot([0,5000],np.log10([7,7]),'k--')
ax[0].set_title('Game scores')
ax[1].plot(np.arange(4991),np.log10(1+np.convolve(np.ones(10)/10,scores,mode='valid')))
ax[1].plot([0,4991],np.log10([7,7]),'k--')
ax[1].set_title('Game scores, average 10 consecutive games')
ax[2].plot(np.arange(0,len(q_achieved)),q_achieved)
ax[2].set_title('Q values of state achieved at each time')
ax[2].set_ylabel('Game number')
# Out:
# Text(0, 0.5, 'Game number')

# %% [markdown]
# Hooray, it has learned!  If you are getting a ten-game average score of better than 6, then you are ready to submit your model for grading.   In order to do that, you need to save the model:

# %%
q_learner.save('trained_model.npz')

# %% [markdown]
# <a id='section9'></a>

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# For extra credit, download the file <a href="mp11_extra.zip">mp11_extra.zip</a>.  The only important file in this package is:
# * `tests/test_extra.py`: this contains extra tests that will evaluate your pre-trained `deep_q` learner, which should be in a file called `trained_model.pkl`.  For full credit, your model should achieve an average score of greater than 20, averaged over 10 consecutive games.
#
# With a quantized lookup table, it's probably not possible to achieve an average score of 20.  With a deep-Q learner, however, it is eminently possible.  In order to do the extra credit, therefore, you should just fill in the part of `submitted.py` that implements the `deep_q` learner, using pytorch to define a model structure, train it, save it, load it, and act on it.  This learner only needs to have five methods: `__init__`, `act`, `learn`, `save`, and `load`:

# %%
importlib.reload(submitted)
help(submitted.deep_q.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst)
#     Create a new deep_q learner.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a deep learning model that will accept
#     (state,action) as input, and estimate Q as the output.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#
#     @return:
#     None

# %%
help(submitted.deep_q.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     You are free to determine your own exploration/exploitation policy --
#     you don't need to use the epsilon and nfirst provided to you.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %%
help(submitted.deep_q.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Perform one iteration of training on a deep-Q model.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 floats, in the same format as state
#
#     @return:
#     None

# %%
help(submitted.deep_q.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your trained deep-Q model to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
help(submitted.deep_q.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load your deep-Q model from a file.
#     This should load from whatever file format your save function
#     used.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## Grade your homework

# %% [markdown]
# If you've reached this point, and all of the above sections work, then you're ready to try grading your homework!  Before you submit it to Gradescope, try grading it on your own machine.  This will run some visible test cases (which you can read in `tests/test_visible.py`), and compare the results to the solutions (which you can read in `solution.json`).
#
# The exclamation point (!) tells python to run the following as a shell command.  Obviously you don't need to run the code this way -- this usage is here just to remind you that you can also, if you wish, run this command in a terminal window.

# %%
# !python grade.py
# Out:
# .....Completed 0 games, 9 rewards, 2137 frames, score 8, max score 8
# Completed 1 games, 19 rewards, 3701 frames, score 9, max score 9
# Completed 2 games, 40 rewards, 8791 frames, score 20, max score 20
# Completed 3 games, 46 rewards, 9800 frames, score 5, max score 20
# Completed 4 games, 59 rewards, 12975 frames, score 12, max score 20
# Completed 5 games, 60 rewards, 13156 frames, score 0, max score 20
# Completed 6 games, 63 rewards, 13947 frames, score 2, max score 20
# Completed 7 games, 70 rewards, 15249 frames, score 6, max score 20
# Completed 8 games, 74 rewards, 16367 frames, score 3, max score 20
# Completed 9 games, 75 rewards, 16621 frames, score 0, max score 20
# .
# ----------------------------------------------------------------------
# Ran 6 tests in 0.243s
#
# OK

# %% [markdown]
# Now you should try uploading your code to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
#
# **Warning:** For this MP you need to update two files, not just one.
# * `trained_model.npz` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
#
# **Warning:** The autograder calculates the average score over ten random games.  If you are getting an average score above 10 almost all the time on your own computer, and if the autograder says you had a score below 10, try resubmitting to see if the next round of random games is better.
#
# **Extra Credit:** Your extra credit should also be uploaded as two files,
# * `trained_model.pkl` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
